# %%
import os
import shutil
import random

# %%
images_folder = "./New Images"
annotations_folder = "./Labels by Leaf"
labeled_images_folder = "./labelled_images"
unlabeled_images_folder = "./unlabelled_images"

# %%
os.makedirs(labeled_images_folder, exist_ok=True)
os.makedirs(unlabeled_images_folder, exist_ok=True)

# %%
all_images = set(os.listdir(images_folder))
all_annotations = {os.path.splitext(f)[0] for f in os.listdir(annotations_folder) if f.endswith('.json')}

# %%
 for image_file in all_images:
    image_name, _ = os.path.splitext(image_file)
    if image_name in all_annotations:
        # Move labeled images
        shutil.move(os.path.join(images_folder, image_file), os.path.join(labeled_images_folder, image_file))
    else:
        # Move unlabeled images
        shutil.move(os.path.join(images_folder, image_file), os.path.join(unlabeled_images_folder, image_file))

print("Separation complete. Labeled and unlabeled images are moved to respective folders.")
# Out:
# Separation complete. Labeled and unlabeled images are moved to respective folders.

# %%
# Paths for splitting
train_folder = "./train-images-rcnn"
val_folder = "./val-images-rcnn"
train_annotations_folder = "./train-labels-rcnn"
val_annotations_folder = "./val-labels-rcnn"

# Create folders if they don't exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(train_annotations_folder, exist_ok=True)
os.makedirs(val_annotations_folder, exist_ok=True)

# %%
labeled_images = os.listdir(labeled_images_folder)

# Create a list of tuples (image_file, annotation_file)
labeled_image_tuples = [(image_file, f"{os.path.splitext(image_file)[0]}.json") for image_file in labeled_images if os.path.exists(os.path.join(annotations_folder, f"{os.path.splitext(image_file)[0]}.json"))]

# Shuffle the list for randomness
random.shuffle(labeled_image_tuples)

# %%
# Define split ratio
split_ratio = 0.8  # 80% for training, 20% for validation
split_index = int(len(labeled_image_tuples) * split_ratio)

# Split into training and validation sets
train_images = labeled_image_tuples[:split_index]
val_images = labeled_image_tuples[split_index:]

# %%
for image_file, annotation_file in train_images:
    shutil.move(os.path.join(labeled_images_folder, image_file), os.path.join(train_folder, image_file))
    shutil.move(os.path.join(annotations_folder, annotation_file), os.path.join(train_annotations_folder, annotation_file))

for image_file, annotation_file in val_images:
    shutil.move(os.path.join(labeled_images_folder, image_file), os.path.join(val_folder, image_file))
    shutil.move(os.path.join(annotations_folder, annotation_file), os.path.join(val_annotations_folder, annotation_file))

print("Splitting complete. Training and validation sets are ready.")
# Out:
# Splitting complete. Training and validation sets are ready.

# %%
from labelme2coco import convert

# Paths for training data
train_labelme_folder = "./train-labels-rcnn"  # Folder containing Labelme JSON files for training
train_output_coco_file = "./train-annotations.json"  # Output COCO file for training

# Convert Labelme annotations to COCO format for training set
# convert(train_labelme_folder, train_output_coco_file)

# Paths for validation data
val_labelme_folder = "./val-labels-rcnn"  # Folder containing Labelme JSON files for validation
val_output_coco_file = "./val-annotations.json"  # Output COCO file for validation

# Convert Labelme annotations to COCO format for validation set
# convert(val_labelme_folder, val_output_coco_file)

print("\nConversion to COCO format completed for both training and validation sets.")
# Out:
# Conversion to COCO format completed for both training and validation sets.

# %%
import os

def find_unlabeled_images(images_folder, labels_folder, image_extension=".jpg", label_extension=".json"):
    # Get a set of all image file names (without extension)
    image_files = set(os.path.splitext(f)[0] for f in os.listdir(images_folder) if f.endswith(image_extension))

    # Get a set of all label file names (without extension)
    label_files = set(os.path.splitext(f)[0] for f in os.listdir(labels_folder) if f.endswith(label_extension))

    # Find images without a corresponding label
    unlabeled_images = image_files - label_files

    if unlabeled_images:
        print(f"Images without corresponding labels ({len(unlabeled_images)}):")
        for img in unlabeled_images:
            print(img + image_extension)
    else:
        print("All images have corresponding labels.")

# Paths to your image and label folders
images_folder = "./val-images-rcnn"
labels_folder = "./val-labels-rcnn"

# Call the function to find and print images without corresponding labels
find_unlabeled_images(images_folder, labels_folder)
# Out:
# All images have corresponding labels.

# %%
import json
import os

def filter_coco_file(coco_file_path, images_folder):
    # Load the COCO file
    with open(coco_file_path, 'r') as f:
        coco_data = json.load(f)

    # Filter out images that do not exist in the images folder
    filtered_images = []
    filtered_annotations = []

    existing_image_paths = set(os.listdir(images_folder))
    print(f"Existing image files in folder: {existing_image_paths}")

    for image in coco_data['images']:
        image_file_name = os.path.basename(image['file_name'])
        if image_file_name in existing_image_paths:
            filtered_images.append(image)
            # Keep annotations for the existing image
            image_id = image['id']
            filtered_annotations.extend(
                [ann for ann in coco_data['annotations'] if ann['image_id'] == image_id]
            )
        else:
            print(f"Image not found: {image_file_name}")

    # Update the COCO data with the filtered lists
    coco_data['images'] = filtered_images
    coco_data['annotations'] = filtered_annotations

    # Save the cleaned COCO file
    cleaned_coco_file_path = coco_file_path.replace('.json', '_cleaned.json')
    with open(cleaned_coco_file_path, 'w') as f:
        json.dump(coco_data, f, indent=4)

    print(f"Filtered {len(filtered_images)} images and {len(filtered_annotations)} annotations.")
    print(f"Filtered COCO file saved at: {cleaned_coco_file_path}")

# Paths to the original COCO files and the folders containing images
train_images_folder = "./train-images-rcnn"
val_images_folder = "./val-images-rcnn"

# Filter the COCO files for both training and validation sets
filter_coco_file("./dataset-3.json", train_images_folder)
filter_coco_file("./dataset-4.json", val_images_folder)
# Out:
# Existing image files in folder: {'IMG_1743.JPG', 'DSCF4317.JPG', 'DSCF4341.JPG', 'DSCF4366.JPG', 'DSCF4291.JPG', 'DSCF4274.JPG', 'IMG_20240728_082241_BEAUTY.jpg', 'DSCF4555.JPG', '20240719_115034AMByGPSMapCamera.jpg', 'IMG_1572.JPG', 'DSCF4414.JPG', 'DSCF4394.JPG', 'DSCF4536.JPG', '20240719_115509AMByGPSMapCamera.jpg', 'DSCF4576.JPG', 'DSCF4340.JPG', 'DSCF4333.JPG', 'IMG_E1025.JPG', 'DSCF4343.JPG', 'IMG_1740.JPG', 'IMG_1577.JPG', 'DSCF4327.JPG', 'DSCF4268.JPG', 'DSCF4494.JPG', 'DSCF4578.JPG', 'DSCF4652.JPG', 'DSCF4383.JPG', 'IMG_E0342 - Copy.JPG', 'DSCF4330.JPG', 'DSCF4467.JPG', 'DSCF4337.JPG', 'DSCF4288.JPG', 'DSCF4450.JPG', 'DSCF4503.JPG', 'DSCF4338.JPG', 'DSCF4504.JPG', 'IMG_20240728_083106_BEAUTY.jpg', 'IMG_E0549.JPG', 'IMG_E0023.JPG', 'DSCF4315.JPG', 'DSCF4480.JPG', 'DSCF4593.JPG', 'IMG_E1014 - Copy.JPG', 'IMG_20240728_081555_BEAUTY.jpg', 'IMG_20240728_095032_BEAUTY.jpg', 'DSCF4372.JPG', 'DSCF4404.JPG', 'IMG_E0795 - Copy.JPG', '20240719_115259AMByGPSMapCamera.jpg', 'DSCF4461.JPG', 'IMG_1579.JPG', 'DSCF4279.JPG', 'DSCF4649.JPG', 'DSCF4535.JPG', '20240719_114939AMByGPSMapCamera.jpg', 'DSCF4440.JPG', 'DSCF4397.JPG', 'DSCF4653.JPG', 'IMG_1731.JPG', 'IMG_E0450.JPG', 'IMG_1592.JPG', 'DSCF4497.JPG', '20240719_114957AMByGPSMapCamera.jpg', 'DSCF4442.JPG', 'IMG_1599.JPG', 'DSCF4345.JPG', 'DSCF4569.JPG', 'DSCF4273.JPG', 'DSCF4501.JPG', 'IMG_1741.JPG', 'DSCF4385.JPG', 'IMG_1641.JPG', 'DSCF4314.JPG', 'DSCF4472.JPG', 'DSCF4403.JPG', 'IMG_20240728_085603_BEAUTY.jpg', 'IMG_1618.JPG', 'DSCF4643.JPG', 'DSCF4568.JPG', '20240719_115136AMByGPSMapCamera.jpg', 'DSCF4422.JPG', 'DSCF4281.JPG', 'DSCF4495.JPG', 'IMG_20240728_083920_BEAUTY.jpg', 'DSCF4381.JPG', 'DSCF4358.JPG', 'IMG_1549.JPG', 'DSCF4400.JPG', 'IMG_1582.JPG', 'DSCF4538.JPG', 'DSCF4475.JPG', 'DSCF4468.JPG', 'DSCF4331.JPG', 'DSCF4532.JPG', 'DSCF4481.JPG', 'DSCF4402.JPG', 'DSCF4530.JPG', 'DSCF4353.JPG', 'DSCF4349.JPG', 'DSCF4436.JPG', 'DSCF4564.JPG', 'IMG_1602.JPG', 'IMG_20240728_081426_BEAUTY.jpg', 'IMG_1737.JPG', 'DSCF4429.JPG', 'DSCF4492.JPG', 'DSCF4389.JPG', 'IMG_1356.JPG', 'IMG_20240728_090712_BEAUTY.jpg', 'IMG_20240728_093533_BEAUTY.jpg', 'DSCF4539.JPG', 'IMG_E1042.JPG', 'IMG_1639.JPG', 'DSCF4332.JPG', 'IMG_1589.JPG', 'DSCF4296.JPG', 'IMG_1692 - Copy.JPG', 'DSCF4473.JPG', 'DSCF4533.JPG', 'IMG_0650.JPG', '20240719_115516AMByGPSMapCamera.jpg', 'DSCF4336.JPG', 'DSCF4386.JPG', 'DSCF4545.JPG', 'DSCF4499.JPG', 'IMG_1569.JPG', 'IMG_1617.JPG', 'DSCF4430.JPG', '20240719_115057AMByGPSMapCamera.jpg', 'DSCF4453.JPG', 'DSCF4434.JPG', 'DSCF4316.JPG', 'DSCF4405.JPG', 'DSCF4342.JPG', 'IMG_20240728_095018_BEAUTY.jpg', '20240719_115053AMByGPSMapCamera.jpg', 'IMG_20240728_081355_BEAUTY.jpg', 'IMG_20240728_082202_BEAUTY.jpg', 'DSCF4479.JPG', 'DSCF4359.JPG', 'DSCF4350.JPG', 'DSCF4451.JPG', 'IMG_1535.JPG', 'IMG_20240728_083537_BEAUTY.jpg', 'IMG_1752.JPG', 'IMG_20240728_081857_BEAUTY.jpg', 'IMG_20240728_090530_BEAUTY.jpg', 'DSCF4433.JPG', 'DSCF4537.JPG', 'DSCF4295.JPG', 'DSCF4655.JPG', 'IMG_1616.JPG', 'DSCF4631.JPG', '20240719_115116AMByGPSMapCamera.jpg', 'DSCF4335.JPG', 'DSCF4441.JPG', 'DSCF4320.JPG', 'IMG_1727.JPG', '20240719_115150AMByGPSMapCamera.jpg', 'DSCF4374.JPG', 'DSCF4354.JPG', 'DSCF4392.JPG', 'DSCF4265.JPG', '20240719_115458AMByGPSMapCamera.jpg', 'DSCF4581.JPG', 'DSCF4393.JPG', 'DSCF4489.JPG', 'IMG_1630.JPG', 'DSCF4301.JPG', 'DSCF4409.JPG', 'DSCF4465.JPG', 'DSCF4365.JPG', 'IMG_1452.JPG', 'DSCF4642.JPG', 'DSCF4460.JPG', 'DSCF4264.JPG', 'IMG_E0815 - Copy.JPG', 'DSCF4448.JPG', 'IMG_1627.JPG', 'DSCF4347.JPG', 'IMG_20240728_084036_BEAUTY.jpg', 'DSCF4464.JPG', 'DSCF4606.JPG', 'DSCF4519.JPG', 'DSCF4544.JPG', 'IMG_1541 - Copy (2).JPG', 'DSCF4534.JPG', 'DSCF4550.JPG', 'DSCF4558.JPG', 'DSCF4445.JPG', 'DSCF4484.JPG', 'IMG_1390.JPG', 'DSCF4626.JPG', '20240719_115322AMByGPSMapCamera.jpg', 'DSCF4435.JPG', 'IMG_1574.JPG', 'IMG_E1015 - Copy.JPG', 'DSCF4378.JPG', 'DSCF4466.JPG', 'DSCF4625.JPG', 'DSCF4367.JPG', 'DSCF4515.JPG', '20240719_115006AMByGPSMapCamera.jpg', 'DSCF4518.JPG', 'IMG_1750.JPG', 'DSCF4361.JPG' ...
# Image not found: DSCF4294.JPG
# Filtered 347 images and 1223 annotations.
# Filtered COCO file saved at: ./dataset-3_cleaned.json
# Existing image files in folder: {'DSCF4656.JPG', 'IMG_1736.JPG', 'DSCF4485.JPG', 'DSCF4278.JPG', 'DSCF4382.JPG', 'DSCF4399.JPG', 'IMG_E1016 - Copy.JPG', 'DSCF4304.JPG', 'DSCF4496.JPG', 'DSCF4520.JPG', 'DSCF4267.JPG', 'DSCF4325.JPG', 'DSCF4266.JPG', 'IMG_E0815.JPG', 'DSCF4603.JPG', 'IMG_1584.JPG', 'DSCF4407.JPG', 'IMG_1434.JPG', 'IMG_1573.JPG', 'IMG_20240728_085622_BEAUTY.jpg', 'DSCF4439.JPG', 'IMG_1739.JPG', 'DSCF4363.JPG', 'DSCF4525.JPG', 'IMG_1619.JPG', 'DSCF4491.JPG', 'DSCF4505.JPG', 'IMG_1733.JPG', 'DSCF4597.JPG', 'DSCF4287.JPG', 'DSCF4644.JPG', 'DSCF4588.JPG', 'IMG_20240728_081610_BEAUTY.jpg', 'IMG_1571.JPG', 'DSCF4328.JPG', 'DSCF4380.JPG', 'IMG_1570.JPG', 'DSCF4375.JPG', 'DSCF4300.JPG', 'IMG_0901.JPG', 'DSCF4285.JPG', 'DSCF4587.JPG', 'IMG_E1021 - Copy.JPG', 'DSCF4428.JPG', 'DSCF4280.JPG', 'DSCF4567.JPG', '20240719_115238AMByGPSMapCamera.jpg', 'IMG_1632 - Copy.JPG', 'IMG_1628.JPG', 'DSCF4476.JPG', 'DSCF4297.JPG', 'IMG_1608.JPG', 'DSCF4510.JPG', 'DSCF4346.JPG', 'DSCF4263.JPG', 'DSCF4360.JPG', 'DSCF4646.JPG', 'DSCF4406.JPG', 'DSCF4444.JPG', 'DSCF4493.JPG', 'DSCF4355.JPG', 'DSCF4270.JPG', 'DSCF4427.JPG', 'IMG_1353.JPG', 'DSCF4413.JPG', 'DSCF4348.JPG', 'DSCF4283.JPG', 'DSCF4657.JPG', 'IMG_20240728_081720_BEAUTY.jpg', 'DSCF4477.JPG', 'DSCF4373.JPG', 'DSCF4511.JPG', 'DSCF4292.JPG', 'DSCF4490.JPG', 'DSCF4410.JPG', 'DSCF4352.JPG', 'DSCF4526.JPG', 'DSCF4272.JPG', 'DSCF4308.JPG', 'DSCF4506.JPG', 'DSCF4561.JPG', 'IMG_1018.JPG', 'DSCF4617.JPG', 'IMG_0322.JPG', '20240719_115144AMByGPSMapCamera.jpg', 'DSCF4290.JPG', 'DSCF4639.JPG'}
# Filtered 87 images and 296 annotations.
# Filtered COCO file saved at: ./dataset-4_cleaned.json

# %%
import detectron2
print("Detectron2 is installed successfully!")
# Out:
# Detectron2 is installed successfully!

# %%
from detectron2.data.datasets import register_coco_instances
from detectron2.config import get_cfg
from detectron2 import model_zoo
from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
import os
import detectron2.utils.logger as detectron2_logger
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.engine import DefaultPredictor
from detectron2.utils.visualizer import Visualizer, ColorMode
import cv2

# %%
train_images_path = "./train-images-rcnn"
train_coco_annotations = "./dataset-3_cleaned.json"
val_images_path = "./val-images-rcnn"
val_coco_annotations = "./dataset-4_cleaned.json"

# %%
if "leaf_dataset_train" in DatasetCatalog.list(): # Updated line to fix the error
    # If registered, remove the existing registration
    DatasetCatalog.remove("leaf_dataset_train")
    MetadataCatalog.remove("leaf_dataset_train")
if "leaf_dataset_val" in DatasetCatalog.list(): # Updated line to fix the error
    # If registered, remove the existing registration
    DatasetCatalog.remove("leaf_dataset_val")
    MetadataCatalog.remove("leaf_dataset_val")

# %%
register_coco_instances("leaf_dataset_train", {}, train_coco_annotations, train_images_path)
register_coco_instances("leaf_dataset_val", {}, val_coco_annotations, val_images_path)

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("leaf_dataset_train",)
cfg.DATASETS.TEST = ("leaf_dataset_val",)
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
cfg.SOLVER.IMS_PER_BATCH = 16
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 1000
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 16
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2  # Set to 3 if you have 3 classes

# %%
cfg.OUTPUT_DIR = "./detectron-output"
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# %%
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)

# Start training
trainer.train()
# Out:
# [10/24 19:01:20 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# WARNING [10/24 19:01:20 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [10/24 19:01:20 d2.data.datasets.coco]: Loaded 347 images in COCO format from ./dataset-3_cleaned.json
# [10/24 19:01:20 d2.data.build]: Removed 0 images with no usable annotations. 347 images left.
# [10/24 19:01:20 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/24 19:01:20 d2.data.build]: Using training sampler TrainingSampler
# [10/24 19:01:20 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/24 19:01:20 d2.data.common]: Serializing 347 elements to byte tensors and concatenating them all ...
# [10/24 19:01:20 d2.data.common]: Serialized dataset takes 0.21 MiB
# [10/24 19:01:20 d2.data.build]: Making batched data loader with batch_size=16
# WARNING [10/24 19:01:20 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [10/24 19:01:20 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (3, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (2, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [10/24 19:01:21 d2.engine.train_loop]: Starting training from iteration 0
# C:\Users\cse10\miniconda3\envs\data-science-env\Lib\site-packages\torch\functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3596.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [10/24 19:01:51 d2.utils.events]:  eta: 0:17:29  iter: 19  total_loss: 2.925  loss_cls: 1.12  loss_box_reg: 0.9344  loss_mask: 0.6949  loss_rpn_cls: 0.1162  loss_rpn_loc: 0.02623    time: 1.0717  last_time: 1.0584  data_time: 0.6027  last_data_time: 0.1984   lr: 4.9953e-06  max_mem: 11411M
# [10/24 19:02:12 d2.utils.events]:  eta: 0:16:36  iter: 39  total_loss: 2.844  loss_cls: 1.051  loss_box_reg: 0.9558  loss_mask: 0.693  loss_rpn_cls: 0.1294  loss_rpn_loc: 0.03064    time: 1.0379  last_time: 1.0128  data_time: 0.1431  last_data_time: 0.1399   lr: 9.9902e-06  max_mem: 11411M
# [10/24 19:02:32 d2.utils.events]:  eta: 0:15:57  iter: 59  total_loss: 2.702  loss_cls: 0.9149  loss_box_reg: 0.9484  loss_mask: 0.6897  loss_rpn_cls: 0.1037  loss_rpn_loc: 0.02745    time: 1.0271  last_time: 1.0019  data_time: 0.1376  last_data_time: 0.1426   lr: 1.4985e-05  max_mem: 11411M
# [10/24 19:02:52 d2.utils.events]:  eta: 0:15:32  iter: 79  total_loss: 2.527  loss_cls: 0.797  loss_box_reg: 0.8949  loss_mask: 0.684  loss_rpn_cls: 0.1025  loss_rpn_loc: 0.02661    time: 1.0222  last_time: 0.9921  data_time: 0.1370  last_data_time: 0.1334   lr: 1.998e-05  max_mem: 11411M
# [10/24 19:03:12 d2.utils.events]:  eta: 0:15:08  iter: 99  total_loss: 2.492  loss_cls: 0.7128  loss_box_reg: 0.98  loss_mask: 0.676  loss_rpn_cls: 0.07631  loss_rpn_loc: 0.02757    time: 1.0175  last_time: 0.9988  data_time: 0.1357  last_data_time: 0.1350   lr: 2.4975e-05  max_mem: 11411M
# [10/24 19:03:32 d2.utils.events]:  eta: 0:14:48  iter: 119  total_loss: 2.368  loss_cls: 0.6617  loss_box_reg: 0.9443  loss_mask: 0.6622  loss_rpn_cls: 0.07364  loss_rpn_loc: 0.02738    time: 1.0170  last_time: 1.0249  data_time: 0.1371  last_data_time: 0.1310   lr: 2.997e-05  max_mem: 11411M
# [10/24 19:03:52 d2.utils.events]:  eta: 0:14:27  iter: 139  total_loss: 2.259  loss_cls: 0.6127  loss_box_reg: 0.9389  loss_mask: 0.6492  loss_rpn_cls: 0.04986  loss_rpn_loc: 0.02301    time: 1.0154  last_time: 1.0222  data_time: 0.1347  last_data_time: 0.1353   lr: 3.4965e-05  max_mem: 11411M
# [10/24 19:04:13 d2.utils.events]:  eta: 0:14:07  iter: 159  total_loss: 2.192  loss_cls: 0.5848  loss_box_reg: 0.9192  loss_mask: 0.6321  loss_rpn_cls: 0.04594  loss_rpn_loc: 0.02274    time: 1.0149  last_time: 1.0246  data_time: 0.1362  last_data_time: 0.1247   lr: 3.996e-05  max_mem: 11411M
# [10/24 19:04:33 d2.utils.events]:  eta: 0:13:47  iter: 179  total_loss: 2.196  loss_cls: 0.5599  loss_box_reg: 0.9345  loss_mask: 0.611  loss_rpn_cls: 0.04497  loss_rpn_loc: 0.02605    time: 1.0151  last_time: 1.0208  data_time: 0.1352  last_data_time: 0.1529   lr: 4.4955e-05  max_mem: 11411M
# [10/24 19:04:53 d2.utils.events]:  eta: 0:13:25  iter: 199  total_loss: 2.102  loss_cls: 0.5285  loss_box_reg: 0.9206  loss_mask: 0.589  loss_rpn_cls: 0.03427  loss_rpn_loc: 0.02136    time: 1.0133  last_time: 0.9993  data_time: 0.1347  last_data_time: 0.1323   lr: 4.995e-05  max_mem: 11411M
# [10/24 19:05:13 d2.utils.events]:  eta: 0:13:03  iter: 219  total_loss: 2.01  loss_cls: 0.4904  loss_box_reg: 0.9368  loss_mask: 0.5535  loss_rpn_cls: 0.02674  loss_rpn_loc: 0.0193    time: 1.0122  last_time: 0.9997  data_time: 0.1345  last_data_time: 0.1420   lr: 5.4945e-05  max_mem: 11411M
# [10/24 19:05:33 d2.utils.events]:  eta: 0:12:43  iter: 239  total_loss: 1.924  loss_cls: 0.4795  loss_box_reg: 0.8929  loss_mask: 0.5221  loss_rpn_cls: 0.02779  loss_rpn_loc: 0.02113    time: 1.0117  last_time: 1.0366  data_time: 0.1358  last_data_time: 0.1331   lr: 5.994e-05  max_mem: 11411M
# [10/24 19:05:53 d2.utils.events]:  eta: 0:12:23  iter: 259  total_loss: 1.841  loss_cls: 0.4374  loss_box_reg: 0.8758  loss_mask: 0.4696  loss_rpn_cls: 0.02055  loss_rpn_loc: 0.02007    time: 1.0108  last_time: 0.9279  data_time: 0.1359  last_data_time: 0.1234   lr: 6.4935e-05  max_mem: 11411M
# [10/24 19:06:13 d2.utils.events]:  eta: 0:12:02  iter: 279  total_loss: 1.759  loss_cls: 0.4234  loss_box_reg: 0.8592  loss_mask: 0.4393  loss_rpn_cls: 0.02424  loss_rpn_loc: 0.02067    time: 1.0099  last_time: 1.0041  data_time: 0.1341  last_data_time: 0.1317   lr: 6.993e-05  max_mem: 11411M
# [10/24 19:06:33 d2.utils.events]:  eta: 0:11:42  iter: 299  total_loss: 1.621  loss_cls: 0.3881  loss_box_reg: 0.8156  loss_mask: 0.3762  loss_rpn_cls: 0.01704  loss_rpn_loc: 0.01787    time: 1.0095  last_time: 1.0230  data_time: 0.1349  last_data_time: 0.1471   lr: 7.4925e-05  max_mem: 11411M
# [10/24 19:06:53 d2.utils.events]:  eta: 0:11:22  iter: 319  total_loss: 1.548  loss_cls: 0.3578  loss_box_reg: 0.7723  loss_mask: 0.341  loss_rpn_cls: 0.01853  loss_rpn_loc: 0.02057    time: 1.0094  last_time: 0.9950  data_time: 0.1388  last_data_time: 0.1277   lr: 7.992e-05  max_mem: 11411M
# [10/24 19:07:14 d2.utils.events]:  eta: 0:11:02  iter: 339  total_loss: 1.421  loss_cls: 0.3363  loss_box_reg: 0.7463  loss_mask: 0.313  loss_rpn_cls: 0.01536  loss_rpn_loc: 0.01858    time: 1.0094  last_time: 0.9986  data_time: 0.1412  last_data_time: 0.1323   lr: 8.4915e-05  max_mem: 11411M
# [10/24 19:07:34 d2.utils.events]:  eta: 0:10:42  iter: 359  total_loss: 1.285  loss_cls: 0.3042  loss_box_reg: 0.6655  loss_mask: 0.2819  loss_rpn_cls: 0.0147  loss_rpn_loc: 0.01902    time: 1.0093  last_time: 1.0083  data_time: 0.1365  last_data_time: 0.1428   lr: 8.991e-05  max_mem: 11411M
# [10/24 19:07:54 d2.utils.events]:  eta: 0:10:22  iter: 379  total_loss: 1.163  loss_cls: 0.2756  loss_box_reg: 0.5946  loss_mask: 0.2395  loss_rpn_cls: 0.01687  loss_rpn_loc: 0.02017    time: 1.0094  last_time: 1.0321  data_time: 0.1383  last_data_time: 0.1327   lr: 9.4905e-05  max_mem: 11411M
# [10/24 19:08:14 d2.utils.events]:  eta: 0:10:03  iter: 399  total_loss: 1.138  loss_cls: 0.2769  loss_box_reg: 0.5757  loss_mask: 0.2369  loss_rpn_cls: 0.01416  loss_rpn_loc: 0.0206    time: 1.0094  last_time: 1.0066  data_time: 0.1396  last_data_time: 0.1383   lr: 9.99e-05  max_mem: 11411M
# [10/24 19:08:35 d2.utils.events]:  eta: 0:09:43  iter: 419  total_loss: 1.107  loss_cls: 0.262  loss_box_reg: 0.5592  loss_mask: 0.2449  loss_rpn_cls: 0.0147  loss_rpn_loc: 0.02136    time: 1.0096  last_time: 1.0106  data_time: 0.1383  last_data_time: 0.1422   lr: 0.0001049  max_mem: 11411M
# [10/24 19:08:55 d2.utils.events]:  eta: 0:09:23  iter: 439  total_loss: 1.011  loss_cls: 0.2305  loss_box_reg: 0.5104  loss_mask: 0.2205  loss_rpn_cls: 0.01228  loss_rpn_loc: 0.01996    time: 1.0098  last_time: 1.0020  data_time: 0.1374  last_data_time: 0.1298   lr: 0.00010989  max_mem: 11411M
# [10/24 19:09:15 d2.utils.events]:  eta: 0:09:03  iter: 459  total_loss: 0.9422  loss_cls: 0.2293  loss_box_reg: 0.4821  loss_mask: 0.2133  loss_rpn_cls: 0.01277  loss_rpn_loc: 0.02149    time: 1.0098  last_time: 1.0314  data_time: 0.1379  last_data_time: 0.1341   lr: 0.00011489  max_mem: 11411M
# [10/24 19:09:36 d2.utils.events]:  eta: 0:08:43  iter: 479  total_loss: 1.001  loss_cls: 0.2382  loss_box_reg: 0.4828  loss_mask: 0.2123  loss_rpn_cls: 0.01458  loss_rpn_loc: 0.02142    time: 1.0101  last_time: 1.0266  data_time: 0.1404  last_data_time: 0.1386   lr: 0.00011988  max_mem: 11411M
# [10/24 19:09:56 d2.utils.events]:  eta: 0:08:23  iter: 499  total_loss: 0.9375  loss_cls: 0.2253  loss_box_reg: 0.4617  loss_mask: 0.2124  loss_rpn_cls: 0.01212  loss_rpn_loc: 0.01952    time: 1.0102  last_time: 1.0365  data_time: 0.1394  last_data_time: 0.1406   lr: 0.00012488  max_mem: 11411M
# [10/24 19:10:16 d2.utils.events]:  eta: 0:08:03  iter: 519  total_loss: 0.9223  loss_cls: 0.2211  loss_box_reg: 0.4568  loss_mask: 0.1971  loss_rpn_cls: 0.01296  loss_rpn_loc: 0.01934    time: 1.0102  last_time: 1.0080  data_time: 0.1374  last_data_time: 0.1403   lr: 0.00012987  max_mem: 11411M
# [10/24 19:10:36 d2.utils.events]:  eta: 0:07:43  iter: 539  total_loss: 0.9017  loss_cls: 0.21  loss_box_reg: 0.4282  loss_mask: 0.1986  loss_rpn_cls: 0.01282  loss_rpn_loc: 0.01865    time: 1.0102  last_time: 0.9970  data_time: 0.1380  last_data_time: 0.1316   lr: 0.00013487  max_mem: 11411M
# [10/24 19:10:56 d2.utils.events]:  eta: 0:07:22  iter: 559  total_loss: 0.8652  loss_cls: 0.1983  loss_box_reg: 0.4098  loss_mask: 0.1976  loss_rpn_cls: 0.01077  loss_rpn_loc: 0.01881    time: 1.0097  last_time: 0.9999  data_time: 0.1374  last_data_time: 0.1350   lr: 0.00013986  max_mem: 11411M
# [10/24 19:11:16 d2.utils.events]:  eta: 0:07:02  iter: 579  total_loss: 0.8498  loss_cls: 0.1972  loss_box_reg: 0.3974  loss_mask: 0.1913  loss_rpn_cls: 0.01191  loss_rpn_loc: 0.01827    time: 1.0095  last_time: 1.0057  data_time: 0.1383  last_data_time: 0.1375   lr: 0.00014486  max_mem: 11411M
# [10/24 19:11:36 d2.utils.events]:  eta: 0:06:42  iter: 599  total_loss: 0.8359  loss_cls: 0.2031  loss_box_reg: 0.3996  loss_mask: 0.2021  loss_rpn_cls: 0.01258  loss_rpn_loc: 0.01775    time: 1.0095  last_time: 1.0028  data_time: 0.1390  last_data_time: 0.1406   lr: 0.00014985  max_mem: 11411M
# [10/24 19:11:57 d2.utils.events]:  eta: 0:06:22  iter: 619  total_loss: 0.8049  loss_cls: 0.199  loss_box_reg: 0.3919  loss_mask: 0.195  loss_rpn_cls: 0.0122  loss_rpn_loc: 0.0169    time: 1.0097  last_time: 1.0001  data_time: 0.1412  last_data_time: 0.1336   lr: 0.00015485  max_mem: 11412M
# [10/24 19:12:28 d2.utils.events]:  eta: 0:06:02  iter: 639  total_loss: 0.7736  loss_cls: 0.1969  loss_box_reg: 0.3654  loss_mask: 0.1906  loss_rpn_cls: 0.01264  loss_rpn_loc: 0.01794    time: 1.0265  last_time: 1.0444  data_time: 0.1459  last_data_time: 0.1383   lr: 0.00015984  max_mem: 11412M
# [10/24 19:12:48 d2.utils.events]:  eta: 0:05:42  iter: 659  total_loss: 0.7738  loss_cls: 0.2002  loss_box_reg: 0.3564  loss_mask: 0.1941  loss_rpn_cls: 0.01067  loss_rpn_loc: 0.01679    time: 1.0264  last_time: 1.0041  data_time: 0.1435  last_data_time: 0.1446   lr: 0.00016484  max_mem: 11412M
# [10/24 19:13:09 d2.utils.events]:  eta: 0:05:22  iter: 679  total_loss: 0.7749  loss_cls: 0.1825  loss_box_reg: 0.3592  loss_mask: 0.2041  loss_rpn_cls: 0.01046  loss_rpn_loc: 0.01657    time: 1.0261  last_time: 1.0225  data_time: 0.1415  last_data_time: 0.1576   lr: 0.00016983  max_mem: 11412M
# [10/24 19:13:29 d2.utils.events]:  eta: 0:05:02  iter: 699  total_loss: 0.782  loss_cls: 0.1907  loss_box_reg: 0.3575  loss_mask: 0.1898  loss_rpn_cls: 0.009349  loss_rpn_loc: 0.01573    time: 1.0256  last_time: 1.0182  data_time: 0.1418  last_data_time: 0.1482   lr: 0.00017483  max_mem: 11412M
# [10/24 19:13:49 d2.utils.events]:  eta: 0:04:42  iter: 719  total_loss: 0.7622  loss_cls: 0.1987  loss_box_reg: 0.3561  loss_mask: 0.1898  loss_rpn_cls: 0.01031  loss_rpn_loc: 0.01529    time: 1.0250  last_time: 1.0054  data_time: 0.1395  last_data_time: 0.1435   lr: 0.00017982  max_mem: 11412M
# [10/24 19:14:09 d2.utils.events]:  eta: 0:04:22  iter: 739  total_loss: 0.7531  loss_cls: 0.1754  loss_box_reg: 0.3567  loss_mask: 0.1872  loss_rpn_cls: 0.01021  loss_rpn_loc: 0.01676    time: 1.0245  last_time: 1.0077  data_time: 0.1375  last_data_time: 0.1411   lr: 0.00018482  max_mem: 11412M
# [10/24 19:14:29 d2.utils.events]:  eta: 0:04:01  iter: 759  total_loss: 0.717  loss_cls: 0.1644  loss_box_reg: 0.3405  loss_mask: 0.1824  loss_rpn_cls: 0.008  loss_rpn_loc: 0.0151    time: 1.0239  last_time: 1.0013  data_time: 0.1384  last_data_time: 0.1368   lr: 0.00018981  max_mem: 11412M
# [10/24 19:14:49 d2.utils.events]:  eta: 0:03:41  iter: 779  total_loss: 0.6869  loss_cls: 0.1624  loss_box_reg: 0.3237  loss_mask: 0.1779  loss_rpn_cls: 0.007656  loss_rpn_loc: 0.01628    time: 1.0235  last_time: 0.9967  data_time: 0.1387  last_data_time: 0.1342   lr: 0.00019481  max_mem: 11412M
# [10/24 19:15:10 d2.utils.events]:  eta: 0:03:21  iter: 799  total_loss: 0.7069  loss_cls: 0.1601  loss_box_reg: 0.3257  loss_mask: 0.1744  loss_rpn_cls: 0.00838  loss_rpn_loc: 0.0149    time: 1.0232  last_time: 0.9876  data_time: 0.1388  last_data_time: 0.1240   lr: 0.0001998  max_mem: 11412M
# [10/24 19:15:30 d2.utils.events]:  eta: 0:03:01  iter: 819  total_loss: 0.6996  loss_cls: 0.1763  loss_box_reg: 0.3159  loss_mask: 0.1813  loss_rpn_cls: 0.008789  loss_rpn_loc: 0.01609    time: 1.0228  last_time: 1.0006  data_time: 0.1386  last_data_time: 0.1274   lr: 0.0002048  max_mem: 11412M
# [10/24 19:15:50 d2.utils.events]:  eta: 0:02:41  iter: 839  total_loss: 0.688  loss_cls: 0.1675  loss_box_reg: 0.33  loss_mask: 0.1738  loss_rpn_cls: 0.009493  loss_rpn_loc: 0.01576    time: 1.0225  last_time: 1.0033  data_time: 0.1383  last_data_time: 0.1384   lr: 0.00020979  max_mem: 11412M
# [10/24 19:16:10 d2.utils.events]:  eta: 0:02:21  iter: 859  total_loss: 0.6883  loss_cls: 0.169  loss_box_reg: 0.3174  loss_mask: 0.1774  loss_rpn_cls: 0.008715  loss_rpn_loc: 0.0155    time: 1.0222  last_time: 1.0067  data_time: 0.1391  last_data_time: 0.1415   lr: 0.00021479  max_mem: 11412M
# [10/24 19:16:30 d2.utils.events]:  eta: 0:02:00  iter: 879  total_loss: 0.7172  loss_cls: 0.167  loss_box_reg: 0.329  loss_mask: 0.1866  loss_rpn_cls: 0.007282  loss_rpn_loc: 0.01582    time: 1.0219  last_time: 0.9863  data_time: 0.1392  last_data_time: 0.1478   lr: 0.00021978  max_mem: 11412M
# [10/24 19:16:51 d2.utils.events]:  eta: 0:01:40  iter: 899  total_loss: 0.6633  loss_cls: 0.1581  loss_box_reg: 0.3016  loss_mask: 0.1618  loss_rpn_cls: 0.008677  loss_rpn_loc: 0.01477    time: 1.0217  last_time: 0.9916  data_time: 0.1387  last_data_time: 0.1277   lr: 0.00022478  max_mem: 11412M
# [10/24 19:17:11 d2.utils.events]:  eta: 0:01:20  iter: 919  total_loss: 0.6391  loss_cls: 0.1449  loss_box_reg: 0.3008  loss_mask: 0.1677  loss_rpn_cls: 0.007216  loss_rpn_loc: 0.01368    time: 1.0215  last_time: 1.0014  data_time: 0.1391  last_data_time: 0.1330   lr: 0.00022977  max_mem: 11412M
# [10/24 19:17:31 d2.utils.events]:  eta: 0:01:00  iter: 939  total_loss: 0.6418  loss_cls: 0.146  loss_box_reg: 0.2978  loss_mask: 0.166  loss_rpn_cls: 0.008652  loss_rpn_loc: 0.01365    time: 1.0213  last_time: 1.0104  data_time: 0.1368  last_data_time: 0.1374   lr: 0.00023477  max_mem: 11412M
# [10/24 19:17:51 d2.utils.events]:  eta: 0:00:40  iter: 959  total_loss: 0.6558  loss_cls: 0.1637  loss_box_reg: 0.3083  loss_mask: 0.1693  loss_rpn_cls: 0.006949  loss_rpn_loc: 0.01598    time: 1.0210  last_time: 1.0221  data_time: 0.1351  last_data_time: 0.1285   lr: 0.00023976  max_mem: 11412M
# [10/24 19:18:12 d2.utils.events]:  eta: 0:00:20  iter: 979  total_loss: 0.6429  loss_cls: 0.1606  loss_box_reg: 0.2945  loss_mask: 0.1619  loss_rpn_cls: 0.007695  loss_rpn_loc: 0.01493    time: 1.0208  last_time: 1.0057  data_time: 0.1350  last_data_time: 0.1363   lr: 0.00024476  max_mem: 11412M
# [10/24 19:18:32 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 0.6431  loss_cls: 0.1616  loss_box_reg: 0.287  loss_mask: 0.1764  loss_rpn_cls: 0.008155  loss_rpn_loc: 0.01602    time: 1.0205  last_time: 1.0069  data_time: 0.1348  last_data_time: 0.1419   lr: 0.00024975  max_mem: 11412M
# [10/24 19:18:32 d2.engine.hooks]: Overall training speed: 998 iterations in 0:16:58 (1.0205 s / it)
# [10/24 19:18:32 d2.engine.hooks]: Total training time: 0:17:00 (0:00:02 on hooks)
# WARNING [10/24 19:18:32 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [10/24 19:18:32 d2.data.datasets.coco]: Loaded 87 images in COCO format from ./dataset-4_cleaned.json
# [10/24 19:18:32 d2.data.build]: Distribution of instances among all 2 categories:
# |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|
# |   maize    | 212          |  turmeric  | 84           |
# |            |              |            |              |
# |   total    | 296          |            |              |
# [10/24 19:18:32 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/24 19:18:32 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/24 19:18:32 d2.data.common]: Serializing 87 elements to byte tensors and concatenating them all ...
# [10/24 19:18:32 d2.data.common]: Serialized dataset takes 0.05 MiB
# WARNING [10/24 19:18:32 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %%
# Validation Code
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

# Setup the evaluator and validation data loader
evaluator = COCOEvaluator("leaf_dataset_val", cfg, False, output_dir="./detectron-output")
val_loader = build_detection_test_loader(cfg, "leaf_dataset_val")

# Evaluate the model
evaluation_results = inference_on_dataset(trainer.model, val_loader, evaluator)
print("Validation Results:", evaluation_results)
# Out:
# WARNING [10/24 19:18:49 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [10/24 19:18:49 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [10/24 19:18:49 d2.data.datasets.coco]: Loaded 87 images in COCO format from ./dataset-4_cleaned.json
# [10/24 19:18:49 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/24 19:18:49 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/24 19:18:49 d2.data.common]: Serializing 87 elements to byte tensors and concatenating them all ...
# [10/24 19:18:49 d2.data.common]: Serialized dataset takes 0.05 MiB
# [10/24 19:18:49 d2.evaluation.evaluator]: Start inference on 87 batches
# [10/24 19:18:57 d2.evaluation.evaluator]: Inference done 11/87. Dataloading: 0.0008 s/iter. Inference: 0.0481 s/iter. Eval: 0.0030 s/iter. Total: 0.0519 s/iter. ETA=0:00:03
# [10/24 19:19:02 d2.evaluation.evaluator]: Total inference time: 0:00:04.991722 (0.060875 s / iter per device, on 1 devices)
# [10/24 19:19:02 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.045937 s / iter per device, on 1 devices)
# [10/24 19:19:02 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/24 19:19:02 d2.evaluation.coco_evaluation]: Saving results to ./detectron-output\coco_instances_results.json
# [10/24 19:19:02 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [10/24 19:19:02 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [10/24 19:19:02 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [10/24 19:19:02 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [10/24 19:19:02 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.283
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.013
# [10/24 19:19:02 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 0.580 | 0.963  | 0.638  | 2.180 | 1.196 | 0.178 |
# [10/24 19:19:02 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP    | category   | AP    |
# |:-----------|:------|:-----------|:------|
# | maize      | 0.164 | turmeric   | 0.996 |
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# [10/24 19:19:02 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [10/24 19:19:02 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [10/24 19:19:02 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [10/24 19:19:02 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.019
# [10/24 19:19:02 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 0.559 | 1.037  | 0.545  | 0.396 | 1.219 | 2.673 |
# [10/24 19:19:02 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP    | category   | AP    |
# |:-----------|:------|:-----------|:------|
# | maize      | 0.161 | turmeric   | 0.958 |
# Validation Results: OrderedDict({'bbox': {'AP': 0.5797616857351039, 'AP50': 0.9634228184596207, 'AP75': 0.6380284112497536, 'APs': 2.1801448597885535, 'APm': 1.1963939450660501, 'APl': 0.17821782178217824, 'AP-maize': 0.16392728569661882, 'AP-turmeric': 0.995596085773589}, 'segm': {'AP': 0.5593863628405603, 'AP50': 1.037331152846555, 'AP75': 0.545279046959142, 'APs': 0.3963180694635869, 'APm': 1.2186424853249491, 'APl': 2.6732673267326734, 'AP-maize': 0.16071737883223797, 'AP-turmeric': 0.9580553468488826}})

# %%
# # Prediction Code
# import os
# import cv2
# import torch
# from detectron2.utils.visualizer import Visualizer
# from detectron2.config import get_cfg
# from detectron2.engine import DefaultPredictor
# from detectron2 import model_zoo
# from detectron2.data import MetadataCatalog

# # Define class names (mapping from index to class name)
# class_names = ["turmeric", "maize"]

# # Setup configuration
# cfg = get_cfg()
# cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
# cfg.MODEL.WEIGHTS = "./detectron-output/model_final.pth"  # Path to the trained weights
# cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # Set threshold for predictions
# cfg.MODEL.DEVICE = "cuda"  # Use "cpu" if you don't have a GPU
# cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2  # Number of classes in the dataset

# # Initialize the predictor
# test_images_folder="./unlabelled_images"

# # Iterate through the test images
# for image_name in os.listdir(test_images_folder):
#     if image_name.endswith(('.png', '.jpg', '.jpeg')):  # Check for valid image formats
#         image_path = os.path.join(test_images_folder, image_name)
#         image = cv2.imread(image_path)

#         # Perform inference
#         outputs = predictor(image)

#         # Get the predicted class indices
#         pred_classes = outputs["instances"].pred_classes.cpu().numpy()

#         # Map the predicted indices to class names
#         predicted_labels = [class_names[i] for i in pred_classes]

#         # Visualize the results
#         v = Visualizer(image[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
#         v = v.draw_instance_predictions(outputs["instances"].to("cpu"))

#         # Save the output image with predictions
#         output_image_path = os.path.join(output_folder, image_name)
#         cv2.imwrite(output_image_path, v.get_image()[:, :, ::-1])  # Convert BGR to RGB for saving

#         # Print or log the predicted labels
#         print(f"Predicted labels for {image_name}: {predicted_labels}")

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog

# Define your class names
classes = ["turmeric", "maize"]

if "leaf_dataset_train" in DatasetCatalog.list(): # Updated line to fix the error
    # If registered, remove the existing registration
    DatasetCatalog.remove("leaf_dataset_train")
    MetadataCatalog.remove("leaf_dataset_train")
if "leaf_dataset_val" in DatasetCatalog.list(): # Updated line to fix the error
    # If registered, remove the existing registration
    DatasetCatalog.remove("leaf_dataset_val")
    MetadataCatalog.remove("leaf_dataset_val")


# Register the datasets
for d in ["train", "val"]:
    DatasetCatalog.register(
        f"leaf_dataset_{d}",
        lambda d=d: load_coco_json(
            f"./dataset-{3 if d == 'train' else 4}_cleaned.json",
            f"./{d}-images-rcnn",
            f"leaf_dataset_{d}"
        )
    )
    MetadataCatalog.get(f"leaf_dataset_{d}").set(thing_classes=classes)

# Update the metadata
leaf_metadata = MetadataCatalog.get("leaf_dataset_train")

# %%
from detectron2.utils.visualizer import Visualizer
from detectron2.utils.visualizer import ColorMode
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor
from detectron2.data import MetadataCatalog
from detectron2 import model_zoo
import cv2
import os
from tqdm import tqdm

# Setup configuration for prediction
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.WEIGHTS = "./output/model_final.pth"  # Path to your trained model
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # Set threshold for prediction
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2  # Update the number of classes to match your dataset
cfg.MODEL.DEVICE = "cuda"  # or "cpu" if no GPU is available

predictor = DefaultPredictor(cfg)

# Use the correct metadata for visualization
leaf_metadata = MetadataCatalog.get("leaf_dataset_train")

test_images_folder = "./unlabelled_images"
output_folder = "./output-predictions"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Predict for each image and track progress with tqdm
for image_name in tqdm(os.listdir(test_images_folder), desc="Processing Images"):
    if image_name.endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(test_images_folder, image_name)
        image = cv2.imread(image_path)

        # Perform inference
        outputs = predictor(image)

        # Visualize results
        v = Visualizer(image[:, :, ::-1], metadata=leaf_metadata, scale=1.2, instance_mode=ColorMode.IMAGE_BW)
        v = v.draw_instance_predictions(outputs["instances"].to("cpu"))

        # Save the visualized output
        output_image_path = os.path.join(output_folder, image_name)
        cv2.imwrite(output_image_path, v.get_image()[:, :, ::-1])  # Convert BGR to RGB for saving
# Out:
# [10/24 19:23:24 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...
# C:\Users\cse10\miniconda3\envs\data-science-env\Lib\site-packages\fvcore\common\checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))
# Processing Images: 100%|█████████████████████████████████████████████████████████████| 666/666 [02:41<00:00,  4.12it/s]

# %%
#On test set

import os
import cv2
import numpy as np
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor
from detectron2 import model_zoo

# Setup configuration for prediction
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.WEIGHTS = "./detectron-output/model_final.pth"  # Path to your trained model
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # Set threshold for prediction
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2  # Update the number of classes to match your dataset
cfg.MODEL.DEVICE = "cuda"  # or "cpu" if no GPU is available

predictor = DefaultPredictor(cfg)

# Folder paths
test_images_folder = "./unlabelled_images"  # Path to your test images folder
output_crops_folder = "./cropped-leaves"  # Path to save cropped shapes

# Create the main output directory if it doesn't exist
if not os.path.exists(output_crops_folder):
    os.makedirs(output_crops_folder)

# Create subfolders for each class
class_names = ["turmeric", "maize"]
for class_name in class_names:
    class_folder = os.path.join(output_crops_folder, class_name)
    if not os.path.exists(class_folder):
        os.makedirs(class_folder)

# Minimum confidence threshold
confidence_threshold = 0.7  # 70% confidence

# Iterate over each test image
for image_name in os.listdir(test_images_folder):
    if image_name.endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(test_images_folder, image_name)
        image = cv2.imread(image_path)

        # Perform inference
        outputs = predictor(image)

        # Get predicted masks, scores, and classes
        masks = outputs["instances"].pred_masks.cpu().numpy()
        scores = outputs["instances"].scores.cpu().numpy()
        classes = outputs["instances"].pred_classes.cpu().numpy()  # Get predicted classes

        # Crop and save each detected leaf using the masks if the score is above the threshold
        for i, (mask, score, cls) in enumerate(zip(masks, scores, classes)):
            if score >= confidence_threshold:
                # Create a binary mask
                binary_mask = mask.astype(np.uint8) * 255

                # Find contours of the mask
                contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                # Create a blank image for cropping
                crop_mask = np.zeros_like(image)

                # Draw the contour on the blank image
                cv2.drawContours(crop_mask, contours, -1, (255, 255, 255), thickness=cv2.FILLED)

                # Mask the original image
                cropped_leaf = cv2.bitwise_and(image, crop_mask)

                # Get bounding box for the contour to crop the relevant part
                x, y, w, h = cv2.boundingRect(contours[0])
                cropped_leaf = cropped_leaf[y:y+h, x:x+w]

                # Determine the class name based on the predicted class
                class_name = class_names[cls]  # Assuming classes are 0 for turmeric and 1 for maize

                # Create a subfolder path for the class
                class_folder = os.path.join(output_crops_folder, class_name)

                # Save the cropped shape
                crop_filename = f"{os.path.splitext(image_name)[0]}_shape_{i}_score_{int(score*100)}.png"
                crop_path = os.path.join(class_folder, crop_filename)
                cv2.imwrite(crop_path, cropped_leaf)

                print(f"Cropped leaf saved at: {crop_path} with score: {score:.2f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
#On train set

import os
import json

# Define the paths
labels_folder = "./train-labels-rcnn"
images_folder = './train-images-rcnn'

# Loop through each JSON file in the labels folder
for filename in os.listdir(labels_folder):
    if filename.endswith('.json'):
        # Full path to the JSON file
        json_path = os.path.join(labels_folder, filename)

        # Open and load the JSON file
        with open(json_path, 'r') as file:
            data = json.load(file)

        # Update the imagePath to include the full path to the images folder
        image_filename = data.get('imagePath', '')
        new_image_path = os.path.join(images_folder, image_filename)

        # Update the imagePath in the JSON data
        data['imagePath'] = new_image_path

        # Save the updated JSON file
        with open(json_path, 'w') as file:
            json.dump(data, file, indent=4)

        print(f'Updated {filename}')

print("All JSON files have been updated.")
# Out:
# Updated 20240719_114939AMByGPSMapCamera.json
# Updated 20240719_114957AMByGPSMapCamera.json
# Updated 20240719_115006AMByGPSMapCamera.json
# Updated 20240719_115020AMByGPSMapCamera.json
# Updated 20240719_115034AMByGPSMapCamera.json
# Updated 20240719_115044AMByGPSMapCamera.json
# Updated 20240719_115053AMByGPSMapCamera.json
# Updated 20240719_115116AMByGPSMapCamera.json
# Updated 20240719_115144AMByGPSMapCamera.json
# Updated 20240719_115150AMByGPSMapCamera.json
# Updated 20240719_115259AMByGPSMapCamera.json
# Updated 20240719_115322AMByGPSMapCamera.json
# Updated 20240719_115136AMByGPSMapCamera.json
# Updated 20240719_115439AMByGPSMapCamera.json
# Updated 20240719_115458AMByGPSMapCamera.json
# Updated 20240719_115512AMByGPSMapCamera.json
# Updated 20240719_115516AMByGPSMapCamera.json
# Updated DSCF4264.json
# Updated DSCF4265.json
# Updated DSCF4268.json
# Updated DSCF4271.json
# Updated DSCF4272.json
# Updated DSCF4273.json
# Updated DSCF4274.json
# Updated DSCF4280.json
# Updated DSCF4281.json
# Updated DSCF4283.json
# Updated DSCF4285.json
# Updated DSCF4286.json
# Updated DSCF4287.json
# Updated DSCF4288.json
# Updated DSCF4289.json
# Updated DSCF4290.json
# Updated DSCF4291.json
# Updated DSCF4292.json
# Updated DSCF4295.json
# Updated DSCF4296.json
# Updated DSCF4297.json
# Updated DSCF4299.json
# Updated DSCF4300.json
# Updated DSCF4301.json
# Updated DSCF4304.json
# Updated DSCF4305.json
# Updated DSCF4307.json
# Updated DSCF4308.json
# Updated DSCF4309.json
# Updated DSCF4310.json
# Updated DSCF4313.json
# Updated DSCF4314.json
# Updated DSCF4315.json
# Updated DSCF4316.json
# Updated DSCF4318.json
# Updated DSCF4323.json
# Updated DSCF4324.json
# Updated DSCF4325.json
# Updated DSCF4326.json
# Updated DSCF4330.json
# Updated DSCF4331.json
# Updated DSCF4332.json
# Updated DSCF4333.json
# Updated DSCF4335.json
# Updated DSCF4337.json
# Updated DSCF4338.json
# Updated DSCF4339.json
# Updated DSCF4340.json
# Updated DSCF4341.json
# Updated DSCF4342.json
# Updated DSCF4343.json
# Updated DSCF4344.json
# Updated DSCF4345.json
# Updated DSCF4347.json
# Updated DSCF4348.json
# Updated DSCF4349.json
# Updated DSCF4351.json
# Updated DSCF4352.json
# Updated DSCF4353.json
# Updated DSCF4354.json
# Updated DSCF4355.json
# Updated DSCF4356.json
# Updated DSCF4358.json
# Updated DSCF4359.json
# Updated DSCF4360.json
# Updated DSCF4361.json
# Updated DSCF4363.json
# Updated DSCF4364.json
# Updated DSCF4365.json
# Updated DSCF4366.json
# Updated DSCF4367.json
# Updated DSCF4369.json
# Updated DSCF4370.json
# Updated DSCF4371.json
# Updated DSCF4372.json
# Updated DSCF4373.json
# Updated DSCF4375.json
# Updated DSCF4376.json
# Updated DSCF4377.json
# Updated DSCF4378.json
# Updated DSCF4379.json
# Updated DSCF4380.json
# Updated DSCF4381.json
# Updated DSCF4382.json
# Updated DSCF4383.json
# Updated DSCF4384.json
# Updated DSCF4385.json
# Updated DSCF4386.json
# Updated DSCF4387.json
# Updated DSCF4388.json
# Updated DSCF4389.json
# Updated DSCF4390.json
# Updated DSCF4391.json
# Updated DSCF4392.json
# Updated DSCF4393.json
# Updated DSCF4395.json
# Updated DSCF4396.json
# Updated DSCF4397.json
# Updated DSCF4399.json
# Updated DSCF4400.json
# Updated DSCF4401.json
# Updated DSCF4402.json
# Updated DSCF4403.json
# Updated DSCF4404.json
# Updated DSCF4405.json
# Updated DSCF4407.json
# Updated DSCF4410.json
# Updated DSCF4412.json
# Updated DSCF4413.json
# Updated DSCF4414.json
# Updated DSCF4418.json
# Updated DSCF4419.json
# Updated DSCF4422.json
# Updated DSCF4424.json
# Updated DSCF4425.json
# Updated DSCF4426.json
# Updated DSCF4427.json
# Updated DSCF4429.json
# Updated DSCF4430.json
# Updated DSCF4433.json
# Updated DSCF4434.json
# Updated DSCF4435.json
# Updated DSCF4439.json
# Updated DSCF4440.json
# Updated DSCF4442.json
# Updated DSCF4444.json
# Updated DSCF4445.json
# Updated DSCF4446.json
# Updated DSCF4448.json
# Updated DSCF4450.json
# Updated DSCF4451.json
# Updated DSCF4454.json
# Updated DSCF4458.json
# Updated DSCF4459.json
# Updated DSCF4460.json
# Updated DSCF4461.json
# Updated DSCF4463.json
# Updated DSCF4464.json
# Updated DSCF4465.json
# Updated DSCF4466.json
# Updated DSCF4467.json
# Updated DSCF4468.json
# Updated DSCF4470.json
# Updated DSCF4474.json
# Updated DSCF4475.json
# Updated DSCF4477.json
# Updated DSCF4478.json
# Updated DSCF4479.json
# Updated DSCF4480.json
# Updated DSCF4481.json
# Updated DSCF4484.json
# Updated DSCF4485.json
# Updated DSCF4489.json
# Updated DSCF4490.json
# Updated DSCF4492.json
# Updated DSCF4493.json
# Updated DSCF4494.json
# Updated DSCF4495.json
# Updated DSCF4496.json
# Updated DSCF4497.json
# Updated DSCF4499.json
# Updated DSCF4500.json
# Updated DSCF4501.json
# Updated DSCF4502.json
# Updated DSCF4503.json
# Updated DSCF4505.json
# Updated DSCF4506.json
# Updated DSCF4507.json
# Updated DSCF4510.json
# Updated DSCF4514.json
# Updated DSCF4515.json
# Updated DSCF4519.json
# Updated DSCF4520.json
# Updated DSCF4523.json
# Updated DSCF4524.json
# Updated DSCF4525.json
# Updated DSCF4526.json
# Updated DSCF4531.json
# Updated DSCF4532.json
# Updated DSCF4533.json
# Updated DSCF4534.json
# Updated DSCF4535.json
# Updated DSCF4536.json
# Updated DSCF4537.json
# Updated DSCF4538.json
# Updated DSCF4545.json
# Updated DSCF4546.json
# Updated DSCF4547.json
# Updated DSCF4548.json
# Updated DSCF4550.json
# Updated DSCF4552.json
# Updated DSCF4554.json
# Updated DSCF4555.json
# Updated DSCF4557.json
# Updated DSCF4564.json
# Updated DSCF4567.json
# Updated DSCF4568.json
# Updated DSCF4570.json
# Updated DSCF4571.json
# Updated DSCF4574.json
# Updated DSCF4576.json
# Updated DSCF4577.json
# Updated DSCF4578.json
# Updated DSCF4581.json
# Updated DSCF4584.json
# Updated DSCF4588.json
# Updated DSCF4593.json
# Updated DSCF4596.json
# Updated DSCF4597.json
# Updated DSCF4599.json
# Updated DSCF4605.json
# Updated DSCF4606.json
# Updated DSCF4607.json
# Updated DSCF4613.json
# Updated DSCF4617.json
# Updated DSCF4621.json
# Updated DSCF4625.json
# Updated DSCF4626.json
# Updated DSCF4631.json
# Updated DSCF4638.json
# Updated DSCF4639.json
# Updated DSCF4640.json
# Updated DSCF4642.json
# Updated DSCF4643.json
# Updated DSCF4646.json
# Updated DSCF4651.json
# Updated DSCF4652.json
# Updated DSCF4653.json
# Updated DSCF4654.json
# Updated DSCF4655.json
# Updated IMG_0281.json
# Updated IMG_0287.json
# Updated IMG_0322.json
# Updated IMG_0650.json
# Updated IMG_0749.json
# Updated IMG_0787.json
# Updated IMG_1001.json
# Updated IMG_1353.json
# Updated IMG_1355.json
# Updated IMG_1356.json
# Updated IMG_1390.json
# Updated IMG_1419.json
# Updated IMG_1434.json
# Updated IMG_1452.json
# Updated IMG_1535.json
# Updated IMG_1566 - Copy (2).json
# Updated IMG_1570.json
# Updated IMG_1571.json
# Updated IMG_1572.json
# Updated IMG_1573.json
# Updated IMG_1574.json
# Updated IMG_1576.json
# Updated IMG_1578.json
# Updated IMG_1579.json
# Updated IMG_1584.json
# Updated IMG_1585.json
# Updated IMG_1587.json
# Updated IMG_1588.json
# Updated IMG_1589.json
# Updated IMG_1592.json
# Updated IMG_1597 - Copy (2).json
# Updated IMG_1602.json
# Updated IMG_1603.json
# Updated IMG_1604.json
# Updated IMG_1606.json
# Updated IMG_1608.json
# Updated IMG_1614.json
# Updated IMG_1616.json
# Updated IMG_1617.json
# Updated IMG_1619.json
# Updated IMG_1627.json
# Updated IMG_1628.json
# Updated IMG_1628 - Copy (2).json
# Updated IMG_1630.json
# Updated IMG_1631 - Copy.json
# Updated IMG_1632 - Copy.json
# Updated IMG_1639.json
# Updated IMG_1641.json
# Updated IMG_1692 - Copy.json
# Updated IMG_1726.json
# Updated IMG_1727.json
# Updated IMG_1728.json
# Updated IMG_1729.json
# Updated IMG_1733.json
# Updated IMG_1735.json
# Updated IMG_1737.json
# Updated IMG_1739.json
# Updated IMG_1740.json
# Updated IMG_1741.json
# Updated IMG_1742.json
# Updated IMG_1743.json
# Updated IMG_1750.json
# Updated IMG_1752.json
# Updated IMG_20240728_081426_BEAUTY.json
# Updated IMG_20240728_081555_BEAUTY.json
# Updated IMG_20240728_081602_BEAUTY.json
# Updated IMG_20240728_081610_BEAUTY.json
# Updated IMG_20240728_081711_BEAUTY.json
# Updated IMG_20240728_081720_BEAUTY.json
# Updated IMG_20240728_082102_BEAUTY.json
# Updated IMG_20240728_082134_BEAUTY.json
# Updated IMG_20240728_082148_BEAUTY.json
# Updated IMG_20240728_082202_BEAUTY.json
# Updated IMG_20240728_082241_BEAUTY.json
# Updated IMG_20240728_082707_BEAUTY.json
# Updated IMG_20240728_082719_BEAUTY.json
# Updated IMG_20240728_083106_BEAUTY.json
# Updated IMG_20240728_083537_BEAUTY.json
# Updated IMG_20240728_083920_BEAUTY.json
# Updated IMG_20240728_084036_BEAUTY.json
# Updated IMG_20240728_085603_BEAUTY.json
# Updated IMG_20240728_085622_BEAUTY.json
# Updated IMG_20240728_090530_BEAUTY.json
# Updated IMG_20240728_090712_BEAUTY.json
# Updated IMG_20240728_093533_BEAUTY.json
# Updated IMG_20240728_095018_BEAUTY.json
# Updated IMG_E0332.json
# Updated IMG_E0023.json
# Updated IMG_E0342 - Copy.json
# Updated IMG_E0450.json
# Updated IMG_E0549.json
# Updated IMG_E0815.json
# Updated IMG_E0795 - Copy.json
# Updated IMG_E0815 - Copy.json
# Updated IMG_E1014 - Copy.json
# Updated IMG_E1014.json
# Updated IMG_E1016 - Copy.json
# Updated IMG_E1021 - Copy.json
# Updated IMG_E1023 - Copy.json
# Updated IMG_E1025.json
# Updated IMG_E1042.json
# All JSON files have been updated.

# %%
#Training set

import os
import cv2
import json
import numpy as np

# Folder paths
labelme_folder = "./train-labels-rcnn"  # Path to your Labelme JSON files
image_folder = "./train-images-rcnn"  # Path where the images are stored
output_crops_folder = "./cropped-leaves-3"  # Path to save cropped shapes

# Create the main output directory if it doesn't exist
if not os.path.exists(output_crops_folder):
    os.makedirs(output_crops_folder)

# Create subfolders for each class
class_names = ["turmeric", "maize"]
for class_name in class_names:
    class_folder = os.path.join(output_crops_folder, class_name)
    if not os.path.exists(class_folder):
        os.makedirs(class_folder)

# Iterate over each JSON file in the Labelme folder
for json_file in os.listdir(labelme_folder):
    if json_file.endswith('.json'):
        json_path = os.path.join(labelme_folder, json_file)

        # Load the JSON file
        with open(json_path) as f:
            data = json.load(f)

        # Modify the imagePath to remove "/../New Images/" and replace it with "/"
        original_image_path = data['imagePath']
        modified_image_path = original_image_path.replace("/../New Images/", "/")
        data['imagePath'] = modified_image_path

        # Load the image using the modified path
        image_path = os.path.join(image_folder, modified_image_path)
        image = cv2.imread(image_path)

        # Check if the image was loaded successfully
        if image is None:
            print(f"Warning: Unable to load image at {image_path}")
            continue  # Skip this JSON file and move to the next one

        # Process each shape in the JSON
        for shape in data['shapes']:
            # Extract polygon points
            points = np.array(shape['points'], dtype=np.int32)
            class_name = shape['label']

            # Create a binary mask from the polygon
            mask = np.zeros(image.shape[:2], dtype=np.uint8)
            cv2.fillPoly(mask, [points], 1)  # Fill the polygon in the mask

            # Find contours of the mask
            contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            # Crop and save each detected leaf using the mask
            for i, contour in enumerate(contours):
                # Create a blank image for cropping
                crop_mask = np.zeros_like(image)

                # Draw the contour on the blank image
                cv2.drawContours(crop_mask, [contour], -1, (255, 255, 255), thickness=cv2.FILLED)

                # Mask the original image
                cropped_leaf = cv2.bitwise_and(image, crop_mask)

                # Get bounding box for the contour to crop the relevant part
                x, y, w, h = cv2.boundingRect(contour)
                cropped_leaf = cropped_leaf[y:y+h, x:x+w]

                # Determine the class folder based on the label
                if class_name in class_names:
                    class_folder = os.path.join(output_crops_folder, class_name)

                    # Save the cropped shape
                    crop_filename = f"{os.path.splitext(json_file)[0]}_shape_{i}.png"
                    crop_path = os.path.join(class_folder, crop_filename)
                    cv2.imwrite(crop_path, cropped_leaf)

                    print(f"Cropped leaf saved at: {crop_path} for class: {class_name}")

        # Save the modified JSON file with the updated imagePath
        with open(json_path, 'w') as f:
            json.dump(data, f, indent=4)

print("Processing complete.")
# Out:
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_114939AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114939AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_114939AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_114939AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114939AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114939AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_114939AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114939AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_114939AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114939AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114939AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114939AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114939AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114939AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_114957AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_114957AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_114957AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_114957AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114957AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_114957AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115006AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115006AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115006AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115020AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115020AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115020AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115020AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115020AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115020AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115020AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115020AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115020AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115034AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115034AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115034AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115034AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115034AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115034AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115034AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115034AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115034AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115034AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115044AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115044AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115044AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115044AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115044AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115044AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115044AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115044AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115044AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115044AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115044AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115044AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115044AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115053AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115053AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115053AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115053AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115053AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115053AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115053AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115053AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115053AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115053AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115053AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115053AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115053AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115116AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115116AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115144AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115144AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115144AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115144AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115144AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115144AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115144AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115144AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115144AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115144AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115150AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115150AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115150AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115150AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115150AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115150AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115150AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115259AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115259AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115259AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115259AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115259AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115259AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115259AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115259AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115259AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115259AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115322AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115322AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115322AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115322AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115322AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115322AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115136AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115136AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115136AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115136AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115136AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115136AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115439AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115439AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115439AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115439AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115439AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115439AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115439AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115439AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115439AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115439AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115458AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115458AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115458AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115458AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115458AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115458AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115512AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115512AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115512AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115512AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115512AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115512AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115512AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115512AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115512AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115512AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115516AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115516AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115516AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115516AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115516AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/20240719_115516AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115516AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115516AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/20240719_115516AMByGPSMapCamera_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4264_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4264_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4265_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4268_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4268_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4268_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4271_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4271_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4272_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4272_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4273_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4273_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4273_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4273_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4274_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4274_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4274_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4274_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4280_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4280_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4281_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4281_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4281_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4281_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4281_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4281_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4283_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4285_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4285_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4286_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4286_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4286_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4286_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4287_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4287_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4287_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4287_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4287_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4287_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4288_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4288_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4288_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4289_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4289_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4290_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4290_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4290_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4290_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4291_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4291_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4291_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4291_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4292_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4292_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4292_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4292_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4292_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4292_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4292_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4292_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4292_shape_0.png for class: maize
# Warning: Unable to load image at /content/drive/My Drive/Colab Notebooks/train-images-rcnn/DSCF4294.JPG
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4296_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4296_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4296_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4297_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4297_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4297_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4299_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4299_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4299_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4299_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4300_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4300_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4301_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4304_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4305_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4307_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4307_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4308_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4308_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4309_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4310_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4310_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4313_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4313_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4313_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4314_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4314_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4315_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4315_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4315_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4316_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4316_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4316_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4318_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4323_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4324_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4325_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4325_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4325_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4326_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4326_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4326_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4326_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4330_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4330_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4330_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4331_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4332_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4333_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4335_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4335_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4335_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4335_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4335_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4337_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4337_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4337_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4337_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4338_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4338_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4339_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4340_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4340_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4341_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4341_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4342_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4343_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4344_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4345_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4345_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4345_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4345_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4347_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4347_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4348_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4348_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4349_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4349_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4349_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4351_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4351_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4352_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4353_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4354_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4355_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4355_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4356_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4356_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4356_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4358_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4358_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4359_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4359_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4359_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4360_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4360_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4360_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4361_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4361_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4361_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4361_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4361_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4361_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4361_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4363_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4363_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4363_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4364_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4365_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4366_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4366_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4366_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4367_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4369_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4369_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4369_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4369_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4369_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/DSCF4369_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4370_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4370_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/DSCF4370_shape_0.png for class: turmeric
# ...
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082241_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082241_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082241_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082241_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082241_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082241_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082707_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082707_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082707_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_082707_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_082707_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_082707_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082719_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_082719_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_082719_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_082719_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_082719_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_082719_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_082719_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083106_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083106_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083106_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083537_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083537_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083537_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083537_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083537_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083537_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083920_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083920_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083920_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_083920_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_084036_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_084036_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_084036_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_084036_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_084036_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_084036_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_084036_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085603_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085603_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085603_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085603_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085603_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_085603_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085622_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085622_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085622_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085622_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085622_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085622_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_085622_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090530_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090530_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090530_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090530_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090530_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090530_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090530_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_090712_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_093533_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_093533_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_093533_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_093533_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_093533_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_093533_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_093533_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_093533_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_20240728_093533_BEAUTY_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_095018_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_095018_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_20240728_095018_BEAUTY_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0332_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0023_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0023_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0023_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0023_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0023_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_E0342 - Copy_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_E0450_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0549_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0549_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/turmeric/IMG_E0815_shape_0.png for class: turmeric
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0795 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0795 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0815 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0815 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E0815 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1014 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1014_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1014_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1014_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1016 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1016 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1021 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1021 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1023 - Copy_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1025_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1042_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1042_shape_0.png for class: maize
# Cropped leaf saved at: /content/drive/My Drive/Colab Notebooks/cropped-leaves-3/maize/IMG_E1042_shape_0.png for class: maize
# Processing complete.
