# %%
import os
import shutil
import random

# %%
images_folder = "./part-2"
annotations_folder = "./part-2 labels"
labeled_images_folder = "./labelled_images"
unlabeled_images_folder = "./unlabelled_images"

# %%
os.makedirs(labeled_images_folder, exist_ok=True)
os.makedirs(unlabeled_images_folder, exist_ok=True)

# %%
all_images = set(os.listdir(images_folder))
all_annotations = {os.path.splitext(f)[0] for f in os.listdir(annotations_folder) if f.endswith('.json')}

# %%
for image_file in all_images:
    image_name, _ = os.path.splitext(image_file)
    if image_name in all_annotations:
        # Move labeled images
        shutil.copy(os.path.join(images_folder, image_file), os.path.join(labeled_images_folder, image_file))
    else:
        # Move unlabeled images
        shutil.copy(os.path.join(images_folder, image_file), os.path.join(unlabeled_images_folder, image_file))

print("Separation complete. Labeled and unlabeled images are moved to respective folders.")
# Out:
# Separation complete. Labeled and unlabeled images are moved to respective folders.

# %%
# Paths for splitting
train_folder = "./train"
val_folder = "./val"
train_annotations_folder = "./train-labels"
val_annotations_folder = "./val-labels"

# Create folders if they don't exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(train_annotations_folder, exist_ok=True)
os.makedirs(val_annotations_folder, exist_ok=True)

# %%
labeled_images = os.listdir(labeled_images_folder)

# Create a list of tuples (image_file, annotation_file)
labeled_image_tuples = [(image_file, f"{os.path.splitext(image_file)[0]}.json") for image_file in labeled_images if os.path.exists(os.path.join(annotations_folder, f"{os.path.splitext(image_file)[0]}.json"))]

# Shuffle the list for randomness
random.shuffle(labeled_image_tuples)

# %%
# Define split ratio
split_ratio = 0.8  # 80% for training, 20% for validation
split_index = int(len(labeled_image_tuples) * split_ratio)

# Split into training and validation sets
train_images = labeled_image_tuples[:split_index]
val_images = labeled_image_tuples[split_index:]

# %%
for image_file, annotation_file in train_images:
    shutil.copy(os.path.join(labeled_images_folder, image_file), os.path.join(train_folder, image_file))
    shutil.copy(os.path.join(annotations_folder, annotation_file), os.path.join(train_annotations_folder, annotation_file))

for image_file, annotation_file in val_images:
    shutil.copy(os.path.join(labeled_images_folder, image_file), os.path.join(val_folder, image_file))
    shutil.copy(os.path.join(annotations_folder, annotation_file), os.path.join(val_annotations_folder, annotation_file))

print("Splitting complete. Training and validation sets are ready.")
# Out:
# Splitting complete. Training and validation sets are ready.

# %%
from labelme2coco import convert

# Paths for training data
train_labelme_folder = "./train-labels"  # Folder containing Labelme JSON files for training
train_output_coco_file = "train-annotations.json"  # Output COCO file for training

# Convert Labelme annotations to COCO format for training set
convert(train_labelme_folder, train_output_coco_file)

# Paths for validation data
val_labelme_folder = "./val-labels"  # Folder containing Labelme JSON files for validation
val_output_coco_file = "val-annotations.json"  # Output COCO file for validation

# Convert Labelme annotations to COCO format for validation set
convert(val_labelme_folder, val_output_coco_file)

print("\nConversion to COCO format completed for both training and validation sets.")
# Out:
# There are 376 listed files in folder ./train-labels.
# Converting labelme annotations to COCO format: 100%|█████████████████████████████████| 376/376 [00:04<00:00, 84.79it/s]
# 11/12/2024 14:53:10 - INFO - labelme2coco -   Converted annotations in COCO format is exported to train-annotations.json\dataset.json
# There are 94 listed files in folder ./val-labels.
# Converting labelme annotations to COCO format: 100%|███████████████████████████████████| 94/94 [00:01<00:00, 82.38it/s]
# 11/12/2024 14:53:12 - INFO - labelme2coco -   Converted annotations in COCO format is exported to val-annotations.json\dataset.json
# Conversion to COCO format completed for both training and validation sets.

# %%
import os

def find_unlabeled_images(images_folder, labels_folder, image_extension=".jpg", label_extension=".json"):
    # Get a set of all image file names (without extension)
    image_files = set(os.path.splitext(f)[0] for f in os.listdir(images_folder) if f.endswith(image_extension))

    # Get a set of all label file names (without extension)
    label_files = set(os.path.splitext(f)[0] for f in os.listdir(labels_folder) if f.endswith(label_extension))

    # Find images without a corresponding label
    unlabeled_images = image_files - label_files

    if unlabeled_images:
        print(f"Images without corresponding labels ({len(unlabeled_images)}):")
        for img in unlabeled_images:
            print(img + image_extension)
    else:
        print("All images have corresponding labels.")

# Paths to your image and label folders
images_folder = "./train"
labels_folder = "./train-labels"

# Call the function to find and print images without corresponding labels
find_unlabeled_images(images_folder, labels_folder)
# Out:
# All images have corresponding labels.

# %%
import json
import os

def filter_coco_file(coco_file_path, images_folder):
    # Load the COCO file
    with open(coco_file_path, 'r') as f:
        coco_data = json.load(f)

    # Filter out images that do not exist in the images folder
    filtered_images = []
    filtered_annotations = []

    existing_image_paths = set(os.listdir(images_folder))
    print(f"Existing image files in folder: {existing_image_paths}")

    for image in coco_data['images']:
        image_file_name = os.path.basename(image['file_name'])
        if image_file_name in existing_image_paths:
            filtered_images.append(image)
            # Keep annotations for the existing image
            image_id = image['id']
            filtered_annotations.extend(
                [ann for ann in coco_data['annotations'] if ann['image_id'] == image_id]
            )
        else:
            print(f"Image not found: {image_file_name}")

    # Update the COCO data with the filtered lists
    coco_data['images'] = filtered_images
    coco_data['annotations'] = filtered_annotations

    # Save the cleaned COCO file
    cleaned_coco_file_path = coco_file_path.replace('.json', '_cleaned.json')
    with open(cleaned_coco_file_path, 'w') as f:
        json.dump(coco_data, f, indent=4)

    print(f"Filtered {len(filtered_images)} images and {len(filtered_annotations)} annotations.")
    print(f"Filtered COCO file saved at: {cleaned_coco_file_path}")

# Paths to the original COCO files and the folders containing images
train_images_folder = "./train"
val_images_folder = "./val"

# Filter the COCO files for both training and validation sets
filter_coco_file("./dataset-3.json", train_images_folder)
filter_coco_file("./dataset-4.json", val_images_folder)
# Out:
# Existing image files in folder: {'IMG_0954(1).JPG', 'DSC05958.JPG', '20240630_110102AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0066.JPG', 'IMG_0069.JPG', 'IMG_0922.JPG', 'IMG_0223.JPG', '20240630_121642PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0731.JPG', 'IMG_0184.JPG', 'IMG_0439.JPG', 'IMG_0650.JPG', 'DSC06083.JPG', 'IMG_0818(1).JPG', '20240630_102546AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0459.JPG', 'IMG_0922(1).JPG', 'IMG_0931(1).JPG', 'IMG_0809.JPG', 'IMG_0862.JPG', '20240701_123050PM_Monday_ByGPSMapCamera.jpg', '20240701_122849PM_Monday_ByGPSMapCamera.jpg', 'IMG_0967.JPG', 'DSC05996.JPG', 'IMG_0887.JPG', '20240630_105554AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0790(1).JPG', 'DSC06046.JPG', '20240630_105940AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0690.JPG', 'IMG_0948(1).JPG', 'IMG_0975.JPG', 'IMG_1011.JPG', 'IMG_0883.JPG', 'IMG_0840.JPG', 'DSC05938.JPG', 'IMG_0914(1).JPG', '20240630_121534PM_Sunday_ByGPSMapCamera.jpg', '20240630_111917AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0245.JPG', 'IMG_0693.JPG', 'IMG_0967(1).JPG', '20240630_74754AMByGPSMapCamera.jpg', 'IMG_0983.JPG', 'DSC06087.JPG', '20240630_111054AM_Sunday_ByGPSMapCamera.jpg', 'DSC05843.JPG', '20240630_74741AMByGPSMapCamera.jpg', 'IMG_0457.JPG', 'IMG_1012.JPG', '20240630_113020AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0992(1).JPG', 'IMG_0871.JPG', 'IMG_0694.JPG', 'IMG_0045.JPG', 'IMG_0438.JPG', 'IMG_0997(1).JPG', '20240630_112247AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0982(1).JPG', '20240630_110058AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0909.JPG', '20240630_102536AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0281.JPG', '20240630_122248PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0337.JPG', 'IMG_0333.JPG', 'IMG_0903.JPG', 'IMG_0879.JPG', '20240630_121316PM_Sunday_ByGPSMapCamera.jpg', 'DSC05882.JPG', 'IMG_0067.JPG', '20240630_110904AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0877(1).JPG', '20240630_110618AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0974(1).JPG', 'IMG_0814(1).JPG', 'DSC05973.JPG', 'IMG_0734.JPG', 'IMG_0838.JPG', 'IMG_0941(1).JPG', 'IMG_0797.JPG', 'IMG_0071.JPG', '20240701_122844PM_Monday_ByGPSMapCamera.jpg', '20240630_121210PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0805(1).JPG', '20240630_110958AM_Sunday_ByGPSMapCamera.jpg', 'DSC05975.JPG', 'IMG_0889.JPG', 'IMG_0994(1).JPG', '20240630_105750AM_Sunday_ByGPSMapCamera.jpg', 'DSC06042.JPG', 'DSC05991.JPG', '20240630_74708AMByGPSMapCamera.jpg', 'DSC06035.JPG', 'IMG_0873(1).JPG', '20240630_111240AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0473.JPG', 'DSC06038.JPG', 'IMG_1010.JPG', 'IMG_0325.JPG', '20240630_121427PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0935(1).JPG', 'DSC05999.JPG', '20240630_102046AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0938.JPG', 'IMG_0458.JPG', '20240630_121753PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0241.JPG', 'DSC05951.JPG', 'DSC06044.JPG', 'IMG_0897.JPG', '20240630_74701AMByGPSMapCamera.jpg', 'DSC05906.JPG', '20240630_121222PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0060.JPG', 'DSC05949.JPG', 'IMG_0226.JPG', 'IMG_0934.JPG', '20240630_121630PM_Sunday_ByGPSMapCamera.jpg', 'DSC06076.JPG', 'IMG_0994.JPG', '20240701_122859PM_Monday_ByGPSMapCamera.jpg', 'IMG_0970(1).JPG', 'IMG_0334.JPG', 'IMG_0882.JPG', 'IMG_0450.JPG', '20240701_122754PM_Monday_ByGPSMapCamera.jpg', 'IMG_0918.JPG', 'IMG_0823(1).JPG', 'IMG_0997.JPG', 'IMG_0338.JPG', '20240630_101925AM_Sunday_ByGPSMapCamera.jpg', '20240630_74526AMByGPSMapCamera.jpg', 'IMG_0187.JPG', 'IMG_0332.JPG', '20240630_120956PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0261.JPG', '20240630_122351PM_Sunday_ByGPSMapCamera.jpg', '20240630_112432AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0888(1).JPG', 'DSC06064.JPG', 'IMG_0863.JPG', '20240701_122656PM_Monday_ByGPSMapCamera.jpg', '20240630_122419PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0512.JPG', 'DSC06008.JPG', 'DSC05979.JPG', 'IMG_0068.JPG', 'IMG_0990.JPG', '20240701_123449PM_Monday_ByGPSMapCamera.jpg', 'IMG_0046.JPG', 'IMG_0937(1).JPG', '20240630_121328PM_Sunday_ByGPSMapCamera.jpg', 'DSC06060.JPG', 'IMG_0836(1).JPG', '20240701_122852PM_Monday_ByGPSMapCamera.jpg', '20240630_110104AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0446.JPG', '20240630_111104A ...
# Filtered 376 images and 1716 annotations.
# Filtered COCO file saved at: ./dataset-3_cleaned.json
# Existing image files in folder: {'IMG_0259.JPG', 'IMG_0927(1).JPG', '20240701_122724PM_Monday_ByGPSMapCamera.jpg', 'DSC06053.JPG', 'IMG_0820(1).JPG', '20240630_74655AMByGPSMapCamera.jpg', 'IMG_0199.JPG', 'IMG_0819(1).JPG', 'IMG_0794(1).JPG', 'IMG_0875(1).JPG', '20240701_122608PM_Monday_ByGPSMapCamera.jpg', 'DSC06022.JPG', 'IMG_0230.JPG', '20240701_122758PM_Monday_ByGPSMapCamera.jpg', '20240630_113301AM_Sunday_ByGPSMapCamera.jpg', 'DSC05970.JPG', 'IMG_0973.JPG', '20240701_122543PM_Monday_ByGPSMapCamera.jpg', 'IMG_0949.JPG', 'DSC05976.JPG', 'DSC05988.JPG', 'IMG_0059.JPG', 'IMG_0790.JPG', '20240701_122720PM_Monday_ByGPSMapCamera.jpg', '20240630_123009PM_Sunday_ByGPSMapCamera.jpg', '20240701_123036PM_Monday_ByGPSMapCamera.jpg', 'DSC05854.JPG', 'DSC05865.JPG', '20240630_121949PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0106.JPG', 'DSC05918.JPG', 'IMG_0787.JPG', '20240630_121035PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0923(1).JPG', '20240630_121657PM_Sunday_ByGPSMapCamera.jpg', '20240630_74734AMByGPSMapCamera.jpg', '20240630_122810PM_Sunday_ByGPSMapCamera.jpg', '20240630_105605AM_Sunday_ByGPSMapCamera.jpg', 'DSC05987.JPG', 'DSC06086.JPG', 'DSC05963.JPG', '20240630_121940PM_Sunday_ByGPSMapCamera.jpg', 'DSC05911.JPG', 'DSC05917.JPG', 'IMG_0065.JPG', 'IMG_0807.JPG', 'IMG_0825.JPG', 'DSC05932.JPG', 'IMG_0951(1).JPG', '20240630_75721AMByGPSMapCamera.jpg', '20240630_101014AM_Sunday_ByGPSMapCamera.jpg', '20240630_111004AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0074.JPG', 'IMG_0268.JPG', 'IMG_0665.JPG', 'IMG_1000.JPG', 'IMG_0996(1).JPG', 'IMG_0839(1).JPG', 'IMG_0696.JPG', '20240630_121303PM_Sunday_ByGPSMapCamera.jpg', 'DSC06014.JPG', 'IMG_0352.JPG', 'DSC06017.JPG', '20240630_112429AM_Sunday_ByGPSMapCamera.jpg', '20240701_122313PM_Monday_ByGPSMapCamera.jpg', '20240630_120819PM_Sunday_ByGPSMapCamera.jpg', 'IMG_0841(1).JPG', '20240630_110900AM_Sunday_ByGPSMapCamera.jpg', '20240630_112408AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0751.JPG', 'DSC06057.JPG', '20240630_102850AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0930(1).JPG', 'DSC05841.JPG', '20240701_122602PM_Monday_ByGPSMapCamera.jpg', '20240630_112133AM_Sunday_ByGPSMapCamera.jpg', 'DSC06010.JPG', 'IMG_0887(1).JPG', 'DSC05964.JPG', 'DSC05989.JPG', '20240630_111705AM_Sunday_ByGPSMapCamera.jpg', 'IMG_0933(1).JPG', 'IMG_0823.JPG', '20240701_122802PM_Monday_ByGPSMapCamera.jpg', 'IMG_0091.JPG', 'DSC06055.JPG', '20240701_122454PM_Monday_ByGPSMapCamera.jpg', 'IMG_1004.JPG', 'IMG_0260.JPG', 'IMG_0981(1).JPG', '20240630_102042AM_Sunday_ByGPSMapCamera.jpg', '20240701_122902PM_Monday_ByGPSMapCamera.jpg', '20240630_75717AMByGPSMapCamera.jpg', 'DSC05934.JPG'}
# Filtered 94 images and 447 annotations.
# Filtered COCO file saved at: ./dataset-4_cleaned.json

# %%
import detectron2
print("Detectron2 is installed successfully!")
# Out:
# Detectron2 is installed successfully!

# %%
from detectron2.data.datasets import register_coco_instances
from detectron2.config import get_cfg
from detectron2 import model_zoo
from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
import os
import detectron2.utils.logger as detectron2_logger
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.engine import DefaultPredictor
from detectron2.utils.visualizer import Visualizer, ColorMode
import cv2

# %%
train_images_path = "./train"
train_coco_annotations = "./dataset-3_cleaned.json"
val_images_path = "./val"
val_coco_annotations = "./dataset-4_cleaned.json"

# %%
if "leaf_dataset_train" in DatasetCatalog.list(): # Updated line to fix the error
    # If registered, remove the existing registration
    DatasetCatalog.remove("leaf_dataset_train")
    MetadataCatalog.remove("leaf_dataset_train")
if "leaf_dataset_val" in DatasetCatalog.list(): # Updated line to fix the error
    # If registered, remove the existing registration
    DatasetCatalog.remove("leaf_dataset_val")
    MetadataCatalog.remove("leaf_dataset_val")

# %%
register_coco_instances("leaf_dataset_train", {}, train_coco_annotations, train_images_path)
register_coco_instances("leaf_dataset_val", {}, val_coco_annotations, val_images_path)

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("leaf_dataset_train",)
cfg.DATASETS.TEST = ("leaf_dataset_val",)
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
cfg.SOLVER.IMS_PER_BATCH = 16
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 1000
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 16
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2  # Set to 3 if you have 3 classes

# %%
cfg.OUTPUT_DIR = "./detectron-output"
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# %%
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)

# Start training
trainer.train()
# Out:
# 11/12/2024 15:00:25 - INFO - detectron2.engine.defaults -   Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# 11/12/2024 15:00:25 - WARNING - detectron2.data.datasets.coco -
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# 11/12/2024 15:00:25 - INFO - detectron2.data.datasets.coco -   Loaded 376 images in COCO format from ./dataset-3_cleaned.json
# 11/12/2024 15:00:25 - INFO - detectron2.data.build -   Removed 0 images with no usable annotations. 376 images left.
# 11/12/2024 15:00:25 - INFO - detectron2.data.dataset_mapper -   [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# 11/12/2024 15:00:25 - INFO - detectron2.data.build -   Using training sampler TrainingSampler
# 11/12/2024 15:00:25 - INFO - detectron2.data.common -   Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# 11/12/2024 15:00:25 - INFO - detectron2.data.common -   Serializing 376 elements to byte tensors and concatenating them all ...
# 11/12/2024 15:00:25 - INFO - detectron2.data.common -   Serialized dataset takes 0.26 MiB
# 11/12/2024 15:00:25 - INFO - detectron2.data.build -   Making batched data loader with batch_size=16
# 11/12/2024 15:00:25 - WARNING - detectron2.solver.build -   SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# 11/12/2024 15:00:25 - INFO - detectron2.checkpoint.detection_checkpoint -   [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# 11/12/2024 15:00:25 - INFO - fvcore.common.checkpoint -   [Checkpointer] Loading from C:\Users\cse10/.torch/iopath_cache\detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600\model_final_f10217.pkl ...
# 11/12/2024 15:00:25 - INFO - fvcore.common.checkpoint -   Reading a file from 'Detectron2 Model Zoo'
# 11/12/2024 15:00:25 - WARNING - fvcore.common.checkpoint -   Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (3, 1024) in the model! You might want to double check if this is expected.
# 11/12/2024 15:00:25 - WARNING - fvcore.common.checkpoint -   Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# 11/12/2024 15:00:25 - WARNING - fvcore.common.checkpoint -   Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# 11/12/2024 15:00:25 - WARNING - fvcore.common.checkpoint -   Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# 11/12/2024 15:00:25 - WARNING - fvcore.common.checkpoint -   Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (2, 256, 1, 1) in the model! You might want to double check if this is expected.
# 11/12/2024 15:00:25 - WARNING - fvcore.common.checkpoint -   Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# 11/12/2024 15:00:25 - WARNING - fvcore.common.checkpoint -   Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# 11/12/2024 15:00:25 - INFO - detectron2.engine.train_loop -   Starting training from iteration 0
# C:\Users\cse10\miniconda3\envs\data-science-env\Lib\site-packages\torch\functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3596.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 11/12/2024 15:02:07 - INFO - detectron2.utils.events -    eta: 0:17:19  iter: 19  total_loss: 3.048  loss_cls: 1.187  loss_box_reg: 0.8982  loss_mask: 0.6951  loss_rpn_cls: 0.204  loss_rpn_loc: 0.04093    time: 1.0720  last_time: 1.0969  data_time: 2.0392  last_data_time: 0.2192   lr: 4.9953e-06  max_mem: 11240M
# 11/12/2024 15:02:30 - INFO - detectron2.utils.events -    eta: 0:16:33  iter: 39  total_loss: 2.929  loss_cls: 1.083  loss_box_reg: 0.9449  loss_mask: 0.6892  loss_rpn_cls: 0.1603  loss_rpn_loc: 0.03818    time: 1.0434  last_time: 1.0399  data_time: 0.1541  last_data_time: 0.1550   lr: 9.9902e-06  max_mem: 11240M
# 11/12/2024 15:02:50 - INFO - detectron2.utils.events -    eta: 0:15:56  iter: 59  total_loss: 2.683  loss_cls: 0.9189  loss_box_reg: 0.9268  loss_mask: 0.6774  loss_rpn_cls: 0.1264  loss_rpn_loc: 0.03846    time: 1.0294  last_time: 1.0362  data_time: 0.1429  last_data_time: 0.1506   lr: 1.4985e-05  max_mem: 11240M
# 11/12/2024 15:03:09 - INFO - detectron2.utils.events -    eta: 0:15:27  iter: 79  total_loss: 2.508  loss_cls: 0.7762  loss_box_reg: 0.9474  loss_mask: 0.6608  loss_rpn_cls: 0.08514  loss_rpn_loc: 0.03622    time: 1.0186  last_time: 0.9342  data_time: 0.1416  last_data_time: 0.1460   lr: 1.998e-05  max_mem: 11240M
# 11/12/2024 15:03:29 - INFO - detectron2.utils.events -    eta: 0:15:04  iter: 99  total_loss: 2.362  loss_cls: 0.6755  loss_box_reg: 0.9747  loss_mask: 0.638  loss_rpn_cls: 0.05752  loss_rpn_loc: 0.03253    time: 1.0148  last_time: 1.0210  data_time: 0.1398  last_data_time: 0.1400   lr: 2.4975e-05  max_mem: 11240M
# 11/12/2024 15:03:50 - INFO - detectron2.utils.events -    eta: 0:14:41  iter: 119  total_loss: 2.25  loss_cls: 0.6055  loss_box_reg: 0.9509  loss_mask: 0.6104  loss_rpn_cls: 0.05443  loss_rpn_loc: 0.03241    time: 1.0128  last_time: 0.9982  data_time: 0.1408  last_data_time: 0.1463   lr: 2.997e-05  max_mem: 11240M
# 11/12/2024 15:04:10 - INFO - detectron2.utils.events -    eta: 0:14:21  iter: 139  total_loss: 2.155  loss_cls: 0.5702  loss_box_reg: 0.9351  loss_mask: 0.5733  loss_rpn_cls: 0.03157  loss_rpn_loc: 0.02979    time: 1.0111  last_time: 0.9845  data_time: 0.1402  last_data_time: 0.1312   lr: 3.4965e-05  max_mem: 11240M
# 11/12/2024 15:04:30 - INFO - detectron2.utils.events -    eta: 0:14:00  iter: 159  total_loss: 2.113  loss_cls: 0.5395  loss_box_reg: 0.9648  loss_mask: 0.5414  loss_rpn_cls: 0.02694  loss_rpn_loc: 0.02822    time: 1.0099  last_time: 0.9977  data_time: 0.1433  last_data_time: 0.1457   lr: 3.996e-05  max_mem: 11240M
# 11/12/2024 15:04:50 - INFO - detectron2.utils.events -    eta: 0:13:39  iter: 179  total_loss: 1.948  loss_cls: 0.499  loss_box_reg: 0.9198  loss_mask: 0.4957  loss_rpn_cls: 0.01989  loss_rpn_loc: 0.02888    time: 1.0088  last_time: 0.9898  data_time: 0.1435  last_data_time: 0.1416   lr: 4.4955e-05  max_mem: 11240M
# 11/12/2024 15:05:10 - INFO - detectron2.utils.events -    eta: 0:13:19  iter: 199  total_loss: 1.891  loss_cls: 0.4713  loss_box_reg: 0.9145  loss_mask: 0.4459  loss_rpn_cls: 0.017  loss_rpn_loc: 0.02634    time: 1.0080  last_time: 0.9898  data_time: 0.1423  last_data_time: 0.1360   lr: 4.995e-05  max_mem: 11240M
# 11/12/2024 15:05:30 - INFO - detectron2.utils.events -    eta: 0:12:59  iter: 219  total_loss: 1.811  loss_cls: 0.4538  loss_box_reg: 0.9153  loss_mask: 0.4005  loss_rpn_cls: 0.01725  loss_rpn_loc: 0.02791    time: 1.0069  last_time: 0.9968  data_time: 0.1417  last_data_time: 0.1441   lr: 5.4945e-05  max_mem: 11240M
# 11/12/2024 15:05:50 - INFO - detectron2.utils.events -    eta: 0:12:38  iter: 239  total_loss: 1.701  loss_cls: 0.4251  loss_box_reg: 0.8925  loss_mask: 0.3559  loss_rpn_cls: 0.01202  loss_rpn_loc: 0.02576    time: 1.0065  last_time: 0.9890  data_time: 0.1423  last_data_time: 0.1421   lr: 5.994e-05  max_mem: 11240M
# 11/12/2024 15:06:10 - INFO - detectron2.utils.events -    eta: 0:12:18  iter: 259  total_loss: 1.61  loss_cls: 0.3953  loss_box_reg: 0.8823  loss_mask: 0.3076  loss_rpn_cls: 0.01436  loss_rpn_loc: 0.02598    time: 1.0061  last_time: 1.0010  data_time: 0.1416  last_data_time: 0.1403   lr: 6.4935e-05  max_mem: 11240M
# 11/12/2024 15:06:30 - INFO - detectron2.utils.events -    eta: 0:11:58  iter: 279  total_loss: 1.521  loss_cls: 0.358  loss_box_reg: 0.834  loss_mask: 0.2732  loss_rpn_cls: 0.01376  loss_rpn_loc: 0.02644    time: 1.0054  last_time: 0.9926  data_time: 0.1386  last_data_time: 0.1367   lr: 6.993e-05  max_mem: 11240M
# 11/12/2024 15:06:50 - INFO - detectron2.utils.events -    eta: 0:11:38  iter: 299  total_loss: 1.438  loss_cls: 0.3461  loss_box_reg: 0.8049  loss_mask: 0.2432  loss_rpn_cls: 0.01141  loss_rpn_loc: 0.02662    time: 1.0050  last_time: 0.9947  data_time: 0.1398  last_data_time: 0.1381   lr: 7.4925e-05  max_mem: 11240M
# 11/12/2024 15:07:10 - INFO - detectron2.utils.events -    eta: 0:11:17  iter: 319  total_loss: 1.325  loss_cls: 0.3152  loss_box_reg: 0.749  loss_mask: 0.2199  loss_rpn_cls: 0.01103  loss_rpn_loc: 0.02831    time: 1.0044  last_time: 0.9785  data_time: 0.1405  last_data_time: 0.1324   lr: 7.992e-05  max_mem: 11240M
# 11/12/2024 15:07:30 - INFO - detectron2.utils.events -    eta: 0:10:57  iter: 339  total_loss: 1.241  loss_cls: 0.2942  loss_box_reg: 0.693  loss_mask: 0.2083  loss_rpn_cls: 0.01111  loss_rpn_loc: 0.02649    time: 1.0041  last_time: 0.9897  data_time: 0.1389  last_data_time: 0.1401   lr: 8.4915e-05  max_mem: 11240M
# 11/12/2024 15:07:50 - INFO - detectron2.utils.events -    eta: 0:10:37  iter: 359  total_loss: 1.128  loss_cls: 0.28  loss_box_reg: 0.6057  loss_mask: 0.198  loss_rpn_cls: 0.01076  loss_rpn_loc: 0.02861    time: 1.0039  last_time: 0.9909  data_time: 0.1415  last_data_time: 0.1395   lr: 8.991e-05  max_mem: 11240M
# 11/12/2024 15:08:10 - INFO - detectron2.utils.events -    eta: 0:10:17  iter: 379  total_loss: 1.033  loss_cls: 0.2542  loss_box_reg: 0.5444  loss_mask: 0.1849  loss_rpn_cls: 0.009244  loss_rpn_loc: 0.0283    time: 1.0036  last_time: 1.0459  data_time: 0.1406  last_data_time: 0.1416   lr: 9.4905e-05  max_mem: 11241M
# 11/12/2024 15:08:30 - INFO - detectron2.utils.events -    eta: 0:09:57  iter: 399  total_loss: 0.9762  loss_cls: 0.2377  loss_box_reg: 0.5076  loss_mask: 0.1796  loss_rpn_cls: 0.01052  loss_rpn_loc: 0.02877    time: 1.0034  last_time: 0.9798  data_time: 0.1415  last_data_time: 0.1318   lr: 9.99e-05  max_mem: 11241M
# 11/12/2024 15:08:50 - INFO - detectron2.utils.events -    eta: 0:09:38  iter: 419  total_loss: 0.8891  loss_cls: 0.2206  loss_box_reg: 0.4714  loss_mask: 0.1715  loss_rpn_cls: 0.009576  loss_rpn_loc: 0.02431    time: 1.0032  last_time: 1.0011  data_time: 0.1403  last_data_time: 0.1428   lr: 0.0001049  max_mem: 11241M
# 11/12/2024 15:09:10 - INFO - detectron2.utils.events -    eta: 0:09:18  iter: 439  total_loss: 0.8657  loss_cls: 0.2238  loss_box_reg: 0.462  loss_mask: 0.1726  loss_rpn_cls: 0.008889  loss_rpn_loc: 0.02242    time: 1.0035  last_time: 1.0244  data_time: 0.1414  last_data_time: 0.1404   lr: 0.00010989  max_mem: 11241M
# 11/12/2024 15:09:30 - INFO - detectron2.utils.events -    eta: 0:08:58  iter: 459  total_loss: 0.873  loss_cls: 0.215  loss_box_reg: 0.4416  loss_mask: 0.1694  loss_rpn_cls: 0.009396  loss_rpn_loc: 0.02653    time: 1.0035  last_time: 0.9970  data_time: 0.1416  last_data_time: 0.1417   lr: 0.00011489  max_mem: 11241M
# 11/12/2024 15:09:50 - INFO - detectron2.utils.events -    eta: 0:08:38  iter: 479  total_loss: 0.837  loss_cls: 0.1959  loss_box_reg: 0.4236  loss_mask: 0.1662  loss_rpn_cls: 0.008065  loss_rpn_loc: 0.02413    time: 1.0031  last_time: 0.9794  data_time: 0.1406  last_data_time: 0.1304   lr: 0.00011988  max_mem: 11241M
# 11/12/2024 15:10:10 - INFO - detectron2.utils.events -    eta: 0:08:18  iter: 499  total_loss: 0.8006  loss_cls: 0.1959  loss_box_reg: 0.4111  loss_mask: 0.1647  loss_rpn_cls: 0.006737  loss_rpn_loc: 0.02306    time: 1.0028  last_time: 0.9933  data_time: 0.1395  last_data_time: 0.1416   lr: 0.00012488  max_mem: 11241M
# 11/12/2024 15:10:30 - INFO - detectron2.utils.events -    eta: 0:07:58  iter: 519  total_loss: 0.7682  loss_cls: 0.2006  loss_box_reg: 0.3799  loss_mask: 0.1625  loss_rpn_cls: 0.008053  loss_rpn_loc: 0.0216    time: 1.0026  last_time: 0.9769  data_time: 0.1392  last_data_time: 0.1308   lr: 0.00012987  max_mem: 11241M
# 11/12/2024 15:10:50 - INFO - detectron2.utils.events -    eta: 0:07:38  iter: 539  total_loss: 0.767  loss_cls: 0.2049  loss_box_reg: 0.3959  loss_mask: 0.1507  loss_rpn_cls: 0.006406  loss_rpn_loc: 0.02342    time: 1.0026  last_time: 0.9926  data_time: 0.1399  last_data_time: 0.1392   lr: 0.00013487  max_mem: 11241M
# 11/12/2024 15:11:10 - INFO - detectron2.utils.events -    eta: 0:07:18  iter: 559  total_loss: 0.7176  loss_cls: 0.1865  loss_box_reg: 0.343  loss_mask: 0.1557  loss_rpn_cls: 0.007542  loss_rpn_loc: 0.02238    time: 1.0028  last_time: 1.0355  data_time: 0.1434  last_data_time: 0.1515   lr: 0.00013986  max_mem: 11241M
# 11/12/2024 15:11:30 - INFO - detectron2.utils.events -    eta: 0:06:58  iter: 579  total_loss: 0.7348  loss_cls: 0.1905  loss_box_reg: 0.3668  loss_mask: 0.1508  loss_rpn_cls: 0.006837  loss_rpn_loc: 0.02148    time: 1.0022  last_time: 1.0270  data_time: 0.1386  last_data_time: 0.1428   lr: 0.00014486  max_mem: 11241M
# 11/12/2024 15:11:50 - INFO - detectron2.utils.events -    eta: 0:06:38  iter: 599  total_loss: 0.71  loss_cls: 0.1664  loss_box_reg: 0.3641  loss_mask: 0.1491  loss_rpn_cls: 0.007094  loss_rpn_loc: 0.02211    time: 1.0020  last_time: 0.9894  data_time: 0.1440  last_data_time: 0.1418   lr: 0.00014985  max_mem: 11241M
# 11/12/2024 15:12:10 - INFO - detectron2.utils.events -    eta: 0:06:18  iter: 619  total_loss: 0.7069  loss_cls: 0.1893  loss_box_reg: 0.3288  loss_mask: 0.1454  loss_rpn_cls: 0.006468  loss_rpn_loc: 0.02067    time: 1.0019  last_time: 0.9923  data_time: 0.1404  last_data_time: 0.1312   lr: 0.00015485  max_mem: 11241M
# 11/12/2024 15:12:30 - INFO - detectron2.utils.events -    eta: 0:05:58  iter: 639  total_loss: 0.7076  loss_cls: 0.1723  loss_box_reg: 0.3581  loss_mask: 0.1485  loss_rpn_cls: 0.006315  loss_rpn_loc: 0.02084    time: 1.0017  last_time: 1.0021  data_time: 0.1408  last_data_time: 0.1493   lr: 0.00015984  max_mem: 11241M
# 11/12/2024 15:12:50 - INFO - detectron2.utils.events -    eta: 0:05:38  iter: 659  total_loss: 0.6819  loss_cls: 0.1619  loss_box_reg: 0.3541  loss_mask: 0.149  loss_rpn_cls: 0.005989  loss_rpn_loc: 0.01938    time: 1.0014  last_time: 0.9983  data_time: 0.1403  last_data_time: 0.1451   lr: 0.00016484  max_mem: 11241M
# 11/12/2024 15:13:10 - INFO - detectron2.utils.events -    eta: 0:05:18  iter: 679  total_loss: 0.675  loss_cls: 0.1688  loss_box_reg: 0.3306  loss_mask: 0.1464  loss_rpn_cls: 0.006263  loss_rpn_loc: 0.0212    time: 1.0014  last_time: 0.9823  data_time: 0.1379  last_data_time: 0.1366   lr: 0.00016983  max_mem: 11241M
# 11/12/2024 15:13:29 - INFO - detectron2.utils.events -    eta: 0:04:58  iter: 699  total_loss: 0.7042  loss_cls: 0.1842  loss_box_reg: 0.3615  loss_mask: 0.1537  loss_rpn_cls: 0.005485  loss_rpn_loc: 0.0211    time: 1.0012  last_time: 1.0002  data_time: 0.1358  last_data_time: 0.1425   lr: 0.00017483  max_mem: 11241M
# 11/12/2024 15:13:49 - INFO - detectron2.utils.events -    eta: 0:04:38  iter: 719  total_loss: 0.6743  loss_cls: 0.1686  loss_box_reg: 0.3242  loss_mask: 0.1453  loss_rpn_cls: 0.005861  loss_rpn_loc: 0.01966    time: 1.0011  last_time: 0.9878  data_time: 0.1375  last_data_time: 0.1397   lr: 0.00017982  max_mem: 11241M
# 11/12/2024 15:14:09 - INFO - detectron2.utils.events -    eta: 0:04:19  iter: 739  total_loss: 0.6718  loss_cls: 0.1543  loss_box_reg: 0.3262  loss_mask: 0.1497  loss_rpn_cls: 0.006194  loss_rpn_loc: 0.02129    time: 1.0009  last_time: 1.0070  data_time: 0.1391  last_data_time: 0.1512   lr: 0.00018482  max_mem: 11241M
# 11/12/2024 15:14:29 - INFO - detectron2.utils.events -    eta: 0:03:59  iter: 759  total_loss: 0.6729  loss_cls: 0.179  loss_box_reg: 0.3269  loss_mask: 0.1486  loss_rpn_cls: 0.005651  loss_rpn_loc: 0.01963    time: 1.0009  last_time: 0.9216  data_time: 0.1419  last_data_time: 0.1364   lr: 0.00018981  max_mem: 11241M
# 11/12/2024 15:14:49 - INFO - detectron2.utils.events -    eta: 0:03:39  iter: 779  total_loss: 0.6562  loss_cls: 0.1624  loss_box_reg: 0.3241  loss_mask: 0.1402  loss_rpn_cls: 0.005049  loss_rpn_loc: 0.0199    time: 1.0008  last_time: 1.0041  data_time: 0.1377  last_data_time: 0.1491   lr: 0.00019481  max_mem: 11241M
# 11/12/2024 15:15:09 - INFO - detectron2.utils.events -    eta: 0:03:19  iter: 799  total_loss: 0.6442  loss_cls: 0.1686  loss_box_reg: 0.3017  loss_mask: 0.1442  loss_rpn_cls: 0.005382  loss_rpn_loc: 0.02092    time: 1.0006  last_time: 0.9832  data_time: 0.1388  last_data_time: 0.1367   lr: 0.0001998  max_mem: 11241M
# 11/12/2024 15:15:29 - INFO - detectron2.utils.events -    eta: 0:02:59  iter: 819  total_loss: 0.658  loss_cls: 0.1664  loss_box_reg: 0.3154  loss_mask: 0.1459  loss_rpn_cls: 0.004645  loss_rpn_loc: 0.01921    time: 1.0002  last_time: 1.0196  data_time: 0.1369  last_data_time: 0.1387   lr: 0.0002048  max_mem: 11241M
# 11/12/2024 15:15:49 - INFO - detectron2.utils.events -    eta: 0:02:39  iter: 839  total_loss: 0.6327  loss_cls: 0.1566  loss_box_reg: 0.3136  loss_mask: 0.1463  loss_rpn_cls: 0.004282  loss_rpn_loc: 0.01862    time: 0.9999  last_time: 0.9914  data_time: 0.1388  last_data_time: 0.1400   lr: 0.00020979  max_mem: 11241M
# 11/12/2024 15:16:09 - INFO - detectron2.utils.events -    eta: 0:02:19  iter: 859  total_loss: 0.6324  loss_cls: 0.1626  loss_box_reg: 0.3053  loss_mask: 0.1467  loss_rpn_cls: 0.004051  loss_rpn_loc: 0.0202    time: 0.9999  last_time: 1.0193  data_time: 0.1382  last_data_time: 0.1336   lr: 0.00021479  max_mem: 11241M
# 11/12/2024 15:16:28 - INFO - detectron2.utils.events -    eta: 0:01:59  iter: 879  total_loss: 0.6421  loss_cls: 0.1528  loss_box_reg: 0.3109  loss_mask: 0.1455  loss_rpn_cls: 0.004047  loss_rpn_loc: 0.01964    time: 0.9996  last_time: 0.9879  data_time: 0.1368  last_data_time: 0.1397   lr: 0.00021978  max_mem: 11241M
# 11/12/2024 15:16:48 - INFO - detectron2.utils.events -    eta: 0:01:39  iter: 899  total_loss: 0.6206  loss_cls: 0.1631  loss_box_reg: 0.2986  loss_mask: 0.1368  loss_rpn_cls: 0.0038  loss_rpn_loc: 0.01973    time: 0.9996  last_time: 0.9781  data_time: 0.1368  last_data_time: 0.1331   lr: 0.00022478  max_mem: 11241M
# 11/12/2024 15:17:09 - INFO - detectron2.utils.events -    eta: 0:01:19  iter: 919  total_loss: 0.6585  loss_cls: 0.1479  loss_box_reg: 0.3167  loss_mask: 0.146  loss_rpn_cls: 0.005936  loss_rpn_loc: 0.02049    time: 0.9998  last_time: 1.0333  data_time: 0.1440  last_data_time: 0.1477   lr: 0.00022977  max_mem: 11241M
# 11/12/2024 15:17:29 - INFO - detectron2.utils.events -    eta: 0:00:59  iter: 939  total_loss: 0.6184  loss_cls: 0.1535  loss_box_reg: 0.3026  loss_mask: 0.1378  loss_rpn_cls: 0.005503  loss_rpn_loc: 0.01809    time: 0.9999  last_time: 1.0285  data_time: 0.1372  last_data_time: 0.1358   lr: 0.00023477  max_mem: 11241M
# 11/12/2024 15:17:49 - INFO - detectron2.utils.events -    eta: 0:00:39  iter: 959  total_loss: 0.588  loss_cls: 0.149  loss_box_reg: 0.2845  loss_mask: 0.133  loss_rpn_cls: 0.003718  loss_rpn_loc: 0.0196    time: 1.0002  last_time: 1.1802  data_time: 0.1422  last_data_time: 0.2134   lr: 0.00023976  max_mem: 11241M
# 11/12/2024 15:18:09 - INFO - detectron2.utils.events -    eta: 0:00:19  iter: 979  total_loss: 0.6385  loss_cls: 0.147  loss_box_reg: 0.319  loss_mask: 0.1402  loss_rpn_cls: 0.004569  loss_rpn_loc: 0.0199    time: 1.0002  last_time: 0.9968  data_time: 0.1396  last_data_time: 0.1480   lr: 0.00024476  max_mem: 11241M
# 11/12/2024 15:18:29 - INFO - fvcore.common.checkpoint -   Saving checkpoint to ./detectron-output\model_final.pth
# 11/12/2024 15:18:30 - INFO - detectron2.utils.events -    eta: 0:00:00  iter: 999  total_loss: 0.631  loss_cls: 0.1366  loss_box_reg: 0.3168  loss_mask: 0.1374  loss_rpn_cls: 0.004753  loss_rpn_loc: 0.01837    time: 0.9998  last_time: 0.9780  data_time: 0.1355  last_data_time: 0.1268   lr: 0.00024975  max_mem: 11241M
# 11/12/2024 15:18:30 - INFO - detectron2.engine.hooks -   Overall training speed: 998 iterations in 0:16:37 (0.9998 s / it)
# 11/12/2024 15:18:30 - INFO - detectron2.engine.hooks -   Total training time: 0:16:41 (0:00:04 on hooks)
# 11/12/2024 15:18:30 - WARNING - detectron2.data.datasets.coco -
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# 11/12/2024 15:18:30 - INFO - detectron2.data.datasets.coco -   Loaded 94 images in COCO format from ./dataset-4_cleaned.json
# 11/12/2024 15:18:30 - INFO - detectron2.data.build -   Distribution of instances among all 2 categories:
# |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|
# |   maize    | 399          |  turmeric  | 48           |
# |            |              |            |              |
# |   total    | 447          |            |              |
# 11/12/2024 15:18:30 - INFO - detectron2.data.dataset_mapper -   [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# 11/12/2024 15:18:30 - INFO - detectron2.data.common -   Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# 11/12/2024 15:18:30 - INFO - detectron2.data.common -   Serializing 94 elements to byte tensors and concatenating them all ...
# 11/12/2024 15:18:30 - INFO - detectron2.data.common -   Serialized dataset takes 0.07 MiB
# 11/12/2024 15:18:30 - WARNING - detectron2.engine.defaults -   No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %%
# Validation Code
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

# Setup the evaluator and validation data loader
evaluator = COCOEvaluator("leaf_dataset_val", cfg, False, output_dir="./detectron-output")
val_loader = build_detection_test_loader(cfg, "leaf_dataset_val")

# Evaluate the model
evaluation_results = inference_on_dataset(trainer.model, val_loader, evaluator)
print("Validation Results:", evaluation_results)
# Out:
# 11/12/2024 15:19:25 - WARNING - detectron2.evaluation.coco_evaluation -   COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# 11/12/2024 15:19:25 - WARNING - detectron2.data.datasets.coco -
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# 11/12/2024 15:19:25 - INFO - detectron2.data.datasets.coco -   Loaded 94 images in COCO format from ./dataset-4_cleaned.json
# 11/12/2024 15:19:25 - INFO - detectron2.data.dataset_mapper -   [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# 11/12/2024 15:19:25 - INFO - detectron2.data.common -   Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# 11/12/2024 15:19:25 - INFO - detectron2.data.common -   Serializing 94 elements to byte tensors and concatenating them all ...
# 11/12/2024 15:19:25 - INFO - detectron2.data.common -   Serialized dataset takes 0.07 MiB
# 11/12/2024 15:19:25 - INFO - detectron2.evaluation.evaluator -   Start inference on 94 batches
# 11/12/2024 15:19:33 - INFO - detectron2.evaluation.evaluator -   Inference done 11/94. Dataloading: 0.0007 s/iter. Inference: 0.0451 s/iter. Eval: 0.0038 s/iter. Total: 0.0497 s/iter. ETA=0:00:04
# 11/12/2024 15:19:38 - INFO - detectron2.evaluation.evaluator -   Total inference time: 0:00:05.359482 (0.060219 s / iter per device, on 1 devices)
# 11/12/2024 15:19:38 - INFO - detectron2.evaluation.evaluator -   Total inference pure compute time: 0:00:04 (0.046116 s / iter per device, on 1 devices)
# 11/12/2024 15:19:38 - INFO - detectron2.evaluation.coco_evaluation -   Preparing results for COCO format ...
# 11/12/2024 15:19:38 - INFO - detectron2.evaluation.coco_evaluation -   Saving results to ./detectron-output\coco_instances_results.json
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.coco_evaluation -   Evaluating predictions with unofficial COCO API...
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.fast_eval_api -   Evaluate annotation type *bbox*
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.fast_eval_api -   COCOeval_opt.evaluate() finished in 0.02 seconds.
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.fast_eval_api -   Accumulating evaluation results...
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.fast_eval_api -   COCOeval_opt.accumulate() finished in 0.01 seconds.
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.coco_evaluation -   Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 63.723 | 87.576 | 75.492 | 59.813 | 70.042 | 75.082 |
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.coco_evaluation -   Per-category bbox AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | maize      | 60.565 | turmeric   | 66.881 |
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.fast_eval_api -   Evaluate annotation type *segm*
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.fast_eval_api -   COCOeval_opt.evaluate() finished in 0.05 seconds.
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.fast_eval_api -   Accumulating evaluation results...
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.fast_eval_api -   COCOeval_opt.accumulate() finished in 0.01 seconds.
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.coco_evaluation -   Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 59.642 | 86.518 | 68.477 | 46.066 | 70.482 | 85.248 |
# 11/12/2024 15:19:39 - INFO - detectron2.evaluation.coco_evaluation -   Per-category segm AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | maize      | 50.317 | turmeric   | 68.967 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.755
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.598
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.751
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.729
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.673
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.772
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.871
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.865
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.685
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.461
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.705
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.852
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.688
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.594
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.762
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
# Validation Results: OrderedDict({'bbox': {'AP': 63.7233774824017, 'AP50': 87.575969165666, 'AP75': 75.49172008820587, 'APs': 59.812640949755625, 'APm': 70.04155307889462, 'APl': 75.08211775847914, 'AP-maize': 60.56529710708135, 'AP-turmeric': 66.88145785772205}, 'segm': {'AP': 59.64196744859696, 'AP50': 86.51821536771538, 'AP75': 68.47719468203167, 'APs': 46.06559591906659, 'APm': 70.48235170744607, 'APl': 85.24752475247524, 'AP-maize': 50.31713069300838, 'AP-turmeric': 68.96680420418554}})

# %%
# # Prediction Code
# import os
# import cv2
# import torch
# from detectron2.utils.visualizer import Visualizer
# from detectron2.config import get_cfg
# from detectron2.engine import DefaultPredictor
# from detectron2 import model_zoo
# from detectron2.data import MetadataCatalog

# # Define class names (mapping from index to class name)
# class_names = ["turmeric", "maize"]

# # Setup configuration
# cfg = get_cfg()
# cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
# cfg.MODEL.WEIGHTS = "./detectron-output/model_final.pth"  # Path to the trained weights
# cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # Set threshold for predictions
# cfg.MODEL.DEVICE = "cuda"  # Use "cpu" if you don't have a GPU
# cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2  # Number of classes in the dataset

# # Initialize the predictor
# test_images_folder="./unlabelled_images"

# # Iterate through the test images
# for image_name in os.listdir(test_images_folder):
#     if image_name.endswith(('.png', '.jpg', '.jpeg')):  # Check for valid image formats
#         image_path = os.path.join(test_images_folder, image_name)
#         image = cv2.imread(image_path)

#         # Perform inference
#         outputs = predictor(image)

#         # Get the predicted class indices
#         pred_classes = outputs["instances"].pred_classes.cpu().numpy()

#         # Map the predicted indices to class names
#         predicted_labels = [class_names[i] for i in pred_classes]

#         # Visualize the results
#         v = Visualizer(image[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
#         v = v.draw_instance_predictions(outputs["instances"].to("cpu"))

#         # Save the output image with predictions
#         output_image_path = os.path.join(output_folder, image_name)
#         cv2.imwrite(output_image_path, v.get_image()[:, :, ::-1])  # Convert BGR to RGB for saving

#         # Print or log the predicted labels
#         print(f"Predicted labels for {image_name}: {predicted_labels}")

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog

# Define your class names
classes = ["maize", "turmeric"]

if "leaf_dataset_train" in DatasetCatalog.list(): # Updated line to fix the error
    # If registered, remove the existing registration
    DatasetCatalog.remove("leaf_dataset_train")
    MetadataCatalog.remove("leaf_dataset_train")
if "leaf_dataset_val" in DatasetCatalog.list(): # Updated line to fix the error
    # If registered, remove the existing registration
    DatasetCatalog.remove("leaf_dataset_val")
    MetadataCatalog.remove("leaf_dataset_val")


# Register the datasets
for d in ["train", "val"]:
    DatasetCatalog.register(
        f"leaf_dataset_{d}",
        lambda d=d: load_coco_json(
            f"./dataset-{3 if d == 'train' else 4}_cleaned.json",
            f"./{d}-images-rcnn",
            f"leaf_dataset_{d}"
        )
    )
    MetadataCatalog.get(f"leaf_dataset_{d}").set(thing_classes=classes)

# Update the metadata
leaf_metadata = MetadataCatalog.get("leaf_dataset_train")

# %%
from detectron2.utils.visualizer import Visualizer
from detectron2.utils.visualizer import ColorMode
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor
from detectron2.data import MetadataCatalog
from detectron2 import model_zoo
import cv2
import os
from tqdm import tqdm

# Setup configuration for prediction
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.WEIGHTS = "./detectron-output/model_final.pth"  # Path to your trained model
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # Set threshold for prediction
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2  # Update the number of classes to match your dataset
cfg.MODEL.DEVICE = "cuda"  # or "cpu" if no GPU is available

predictor = DefaultPredictor(cfg)

# Use the correct metadata for visualization
leaf_metadata = MetadataCatalog.get("leaf_dataset_train")

test_images_folder = "./unlabelled_images"
output_folder = "./output-predictions"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Predict for each image and track progress with tqdm
for image_name in tqdm(os.listdir(test_images_folder), desc="Processing Images"):
    if image_name.endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(test_images_folder, image_name)
        image = cv2.imread(image_path)

        # Perform inference
        outputs = predictor(image)

        # Visualize results
        v = Visualizer(image[:, :, ::-1], metadata=leaf_metadata, scale=1.2, instance_mode=ColorMode.IMAGE_BW)
        v = v.draw_instance_predictions(outputs["instances"].to("cpu"))

        # Save the visualized output
        output_image_path = os.path.join(output_folder, image_name)
        cv2.imwrite(output_image_path, v.get_image()[:, :, ::-1])  # Convert BGR to RGB for saving
# Out:
# 11/12/2024 15:20:51 - INFO - detectron2.checkpoint.detection_checkpoint -   [DetectionCheckpointer] Loading from ./detectron-output/model_final.pth ...
# 11/12/2024 15:20:51 - INFO - fvcore.common.checkpoint -   [Checkpointer] Loading from ./detectron-output/model_final.pth ...
# C:\Users\cse10\miniconda3\envs\data-science-env\Lib\site-packages\fvcore\common\checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))
# Processing Images: 100%|███████████████████████████████████████████████████████████| 3646/3646 [12:54<00:00,  4.71it/s]

# %%
#On test set

import os
import cv2
import numpy as np
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor
from detectron2 import model_zoo

# Setup configuration for prediction
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.WEIGHTS = "./detectron-output/model_final.pth"  # Path to your trained model
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # Set threshold for prediction
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2  # Update the number of classes to match your dataset
cfg.MODEL.DEVICE = "cuda"  # or "cpu" if no GPU is available

predictor = DefaultPredictor(cfg)

# Folder paths
test_images_folder = "./unlabelled_images"  # Path to your test images folder
output_crops_folder = "./cropped-leaves"  # Path to save cropped shapes

# Create the main output directory if it doesn't exist
if not os.path.exists(output_crops_folder):
    os.makedirs(output_crops_folder)

# Create subfolders for each class
class_names = ["maize", "turmeric"]
for class_name in class_names:
    class_folder = os.path.join(output_crops_folder, class_name)
    if not os.path.exists(class_folder):
        os.makedirs(class_folder)

# Minimum confidence threshold
confidence_threshold = 0.7  # 70% confidence

# Iterate over each test image
for image_name in os.listdir(test_images_folder):
    if image_name.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(test_images_folder, image_name)
        image = cv2.imread(image_path)

        # Perform inference
        outputs = predictor(image)

        # Get predicted masks, scores, and classes
        masks = outputs["instances"].pred_masks.cpu().numpy()
        scores = outputs["instances"].scores.cpu().numpy()
        classes = outputs["instances"].pred_classes.cpu().numpy()  # Get predicted classes

        # Crop and save each detected leaf using the masks if the score is above the threshold
        for i, (mask, score, cls) in enumerate(zip(masks, scores, classes)):
            if score >= confidence_threshold:
                # Create a binary mask
                binary_mask = mask.astype(np.uint8) * 255

                # Find contours of the mask
                contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                # Create a blank image for cropping
                crop_mask = np.zeros_like(image)

                # Draw the contour on the blank image
                cv2.drawContours(crop_mask, contours, -1, (255, 255, 255), thickness=cv2.FILLED)

                # Mask the original image
                cropped_leaf = cv2.bitwise_and(image, crop_mask)

                # Get bounding box for the contour to crop the relevant part
                x, y, w, h = cv2.boundingRect(contours[0])
                cropped_leaf = cropped_leaf[y:y+h, x:x+w]

                # Determine the class name based on the predicted class
                class_name = class_names[cls]  # Assuming classes are 0 for turmeric and 1 for maize

                # Create a subfolder path for the class
                class_folder = os.path.join(output_crops_folder, class_name)

                # Save the cropped shape
                crop_filename = f"{os.path.splitext(image_name)[0]}_shape_{i}_score_{int(score*100)}.png"
                crop_path = os.path.join(class_folder, crop_filename)
                cv2.imwrite(crop_path, cropped_leaf)

                print(f"Cropped leaf saved at: {crop_path} with score: {score:.2f}")
# Out:
# 11/12/2024 15:38:04 - INFO - detectron2.checkpoint.detection_checkpoint -   [DetectionCheckpointer] Loading from ./detectron-output/model_final.pth ...
# 11/12/2024 15:38:04 - INFO - fvcore.common.checkpoint -   [Checkpointer] Loading from ./detectron-output/model_final.pth ...
# C:\Users\cse10\miniconda3\envs\data-science-env\Lib\site-packages\fvcore\common\checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))
# Cropped leaf saved at: ./cropped-leaves\maize\20240630_101020AM_Sunday_ByGPSMapCamera_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\20240630_101020AM_Sunday_ByGPSMapCamera_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\20240630_101020AM_Sunday_ByGPSMapCamera_shape_2_score_82.png with score: 0.82
# Cropped leaf saved at: ./cropped-leaves\maize\20240630_101020AM_Sunday_ByGPSMapCamera_shape_3_score_74.png with score: 0.75
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0697_shape_0_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0697_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0697_shape_2_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0697_shape_3_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0806(1)_shape_0_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0806(1)_shape_1_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0806(1)_shape_2_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0806(1)_shape_3_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0806(1)_shape_4_score_91.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0806(1)_shape_5_score_88.png with score: 0.88
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_0806(1)_shape_6_score_87.png with score: 0.88
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0806(1)_shape_7_score_83.png with score: 0.84
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0830_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0830_shape_1_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0830_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0830_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0830_shape_4_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0830_shape_5_score_90.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0842_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0842_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0842_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0842_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0842_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0842_shape_5_score_87.png with score: 0.87
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0842_shape_6_score_79.png with score: 0.79
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0843_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0843_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0843_shape_2_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0843_shape_3_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0843_shape_4_score_94.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0844_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0844_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0844_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0844_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0844_shape_4_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0844_shape_5_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0846_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0846_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0846_shape_2_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0846_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0846_shape_4_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0846_shape_5_score_88.png with score: 0.88
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0846_shape_6_score_81.png with score: 0.81
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0847_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0847_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0847_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0847_shape_3_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0847_shape_4_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0847_shape_5_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0847_shape_6_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_0847_shape_7_score_73.png with score: 0.73
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0848_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0848_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0848_shape_2_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0848_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0848_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0848_shape_5_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0848_shape_6_score_89.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0848_shape_7_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0850_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0850_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0850_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0850_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0850_shape_4_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0850_shape_5_score_75.png with score: 0.76
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0852_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0852_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0852_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0852_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0853_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0853_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0853_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0853_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0853_shape_4_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0853_shape_5_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0853_shape_6_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0853_shape_7_score_85.png with score: 0.85
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0853_shape_8_score_70.png with score: 0.70
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854(1)_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854(1)_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854(1)_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854(1)_shape_3_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854(1)_shape_4_score_92.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854(1)_shape_5_score_85.png with score: 0.86
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854(1)_shape_6_score_81.png with score: 0.82
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0854_shape_4_score_86.png with score: 0.87
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0859_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0859_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0859_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0859_shape_3_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0859_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0859_shape_5_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0859_shape_6_score_89.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0859_shape_7_score_87.png with score: 0.88
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0859_shape_8_score_77.png with score: 0.77
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0861_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0861_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0861_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0861_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0861_shape_4_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0861_shape_5_score_91.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0868_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0868_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0868_shape_2_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0868_shape_3_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0868_shape_4_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0878(1)_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0878(1)_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0890(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0890(1)_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0890(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0890(1)_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0890(1)_shape_4_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892(1)_shape_1_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892(1)_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892(1)_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892(1)_shape_4_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892(1)_shape_5_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892(1)_shape_6_score_86.png with score: 0.87
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892(1)_shape_7_score_81.png with score: 0.82
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892(1)_shape_8_score_71.png with score: 0.71
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892_shape_4_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892_shape_5_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0892_shape_6_score_82.png with score: 0.82
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0894_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0894_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0894_shape_2_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0894_shape_3_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0895_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0895_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0895_shape_2_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0895_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0895_shape_4_score_88.png with score: 0.88
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0895_shape_5_score_87.png with score: 0.87
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0895_shape_6_score_74.png with score: 0.74
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0896(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0896(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0903(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0903(1)_shape_1_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0903(1)_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0903(1)_shape_3_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0903(1)_shape_4_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0903(1)_shape_5_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0903(1)_shape_6_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0903(1)_shape_7_score_86.png with score: 0.87
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0910_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0910_shape_1_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0910_shape_2_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0910_shape_3_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0910_shape_4_score_93.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0912_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0912_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0912_shape_2_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0912_shape_3_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0912_shape_4_score_90.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0912_shape_5_score_82.png with score: 0.83
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0987_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0987_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0987_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0987_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0987_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0987_shape_5_score_89.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0987_shape_6_score_80.png with score: 0.80
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0988_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0988_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0988_shape_2_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0988_shape_3_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0988_shape_4_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0989(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0989(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0989(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0989(1)_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0989(1)_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0989(1)_shape_5_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0989(1)_shape_6_score_91.png with score: 0.92
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0989(1)_shape_7_score_75.png with score: 0.76
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0992_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0992_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0992_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0992_shape_3_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0992_shape_4_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_0992_shape_5_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1003_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1003_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1003_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1003_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1003_shape_4_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1003_shape_5_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1003_shape_6_score_75.png with score: 0.75
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1004(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1004(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1004(1)_shape_2_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_4_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_5_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_6_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_7_score_94.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_8_score_89.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005(1)_shape_9_score_86.png with score: 0.87
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_4_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_5_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_6_score_93.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_7_score_90.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_8_score_84.png with score: 0.85
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1005_shape_9_score_78.png with score: 0.79
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1006_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1006_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1006_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1006_shape_3_score_94.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007(1)_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007(1)_shape_3_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007(1)_shape_4_score_94.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007_shape_4_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007_shape_5_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007_shape_6_score_93.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007_shape_7_score_93.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1007_shape_8_score_82.png with score: 0.83
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1008(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1008(1)_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1008(1)_shape_2_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1008(1)_shape_3_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1008(1)_shape_4_score_93.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1008(1)_shape_5_score_86.png with score: 0.86
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1009(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1009(1)_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1009(1)_shape_2_score_89.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1009(1)_shape_3_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1010(1)_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1010(1)_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1010(1)_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1010(1)_shape_3_score_85.png with score: 0.86
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1011(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1011(1)_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1011(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1015(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1015(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1015(1)_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1015(1)_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1015(1)_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1015(1)_shape_5_score_87.png with score: 0.88
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1018_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1018_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1018_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1018_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1018_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1018_shape_5_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1018_shape_6_score_93.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1018_shape_7_score_80.png with score: 0.81
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1019_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1019_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1019_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1019_shape_3_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1019_shape_4_score_84.png with score: 0.85
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1019_shape_5_score_82.png with score: 0.82
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1021_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1021_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1021_shape_2_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1021_shape_3_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1021_shape_4_score_75.png with score: 0.76
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1023(1)_shape_0_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1023(1)_shape_1_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1024(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1024(1)_shape_1_score_71.png with score: 0.72
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1024_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1026(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1026(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1027(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1027(1)_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1028(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1028(1)_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1028(1)_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1028(1)_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1028(1)_shape_4_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1028_shape_0_score_85.png with score: 0.86
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1030_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1030_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1030_shape_2_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1030_shape_3_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1031(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1031(1)_shape_1_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1031(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1031(1)_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1031(1)_shape_4_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1031(1)_shape_5_score_85.png with score: 0.85
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1032(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1032(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1032(1)_shape_2_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1032(1)_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1032(1)_shape_4_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033(1)_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033(1)_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033(1)_shape_4_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033(1)_shape_5_score_79.png with score: 0.79
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033_shape_4_score_93.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033_shape_5_score_90.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1033_shape_6_score_80.png with score: 0.80
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1034(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1034(1)_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1034(1)_shape_2_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1034_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1034_shape_1_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1034_shape_2_score_82.png with score: 0.83
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1035_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1035_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1036(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1036(1)_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1036(1)_shape_2_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1036(1)_shape_3_score_90.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1036(1)_shape_4_score_89.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1036(1)_shape_5_score_89.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1039(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1039(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1039(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1039(1)_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1039(1)_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1039(1)_shape_5_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1040_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1040_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1040_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1040_shape_3_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1040_shape_4_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1040_shape_5_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1040_shape_6_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1040_shape_7_score_92.png with score: 0.92
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1040_shape_8_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1041(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1041(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1041(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1041_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1041_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1041_shape_2_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1041_shape_3_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1041_shape_4_score_83.png with score: 0.83
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_5_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_6_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_7_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_8_score_91.png with score: 0.92
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_9_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_10_score_88.png with score: 0.88
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_11_score_88.png with score: 0.88
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_12_score_84.png with score: 0.84
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1043(1)_shape_13_score_74.png with score: 0.74
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1044(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1044(1)_shape_1_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1044(1)_shape_2_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1044(1)_shape_3_score_81.png with score: 0.81
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1044_shape_0_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1044_shape_1_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1045(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1045(1)_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1045(1)_shape_2_score_91.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1047_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1047_shape_1_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1047_shape_2_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1047_shape_3_score_94.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1047_shape_4_score_94.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_1_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_2_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_3_score_92.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_4_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_5_score_84.png with score: 0.84
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_6_score_81.png with score: 0.82
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_7_score_79.png with score: 0.79
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_8_score_77.png with score: 0.77
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1048(1)_shape_9_score_71.png with score: 0.72
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1051(1)_shape_0_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1051(1)_shape_1_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1051(1)_shape_2_score_93.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1051_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1051_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1051_shape_2_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1051_shape_3_score_87.png with score: 0.87
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1051_shape_4_score_83.png with score: 0.84
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1051_shape_5_score_74.png with score: 0.75
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1052(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1052(1)_shape_1_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1052(1)_shape_2_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1052(1)_shape_3_score_70.png with score: 0.70
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1052_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1052_shape_1_score_79.png with score: 0.79
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056(1)_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056(1)_shape_4_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056(1)_shape_5_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056(1)_shape_6_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056_shape_1_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1056_shape_4_score_89.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057(1)_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057(1)_shape_3_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057(1)_shape_4_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057(1)_shape_5_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057(1)_shape_6_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057(1)_shape_7_score_93.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057_shape_4_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057_shape_5_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057_shape_6_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057_shape_7_score_86.png with score: 0.87
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1057_shape_8_score_78.png with score: 0.79
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1058_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1058_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1058_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1058_shape_3_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1058_shape_4_score_91.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1060_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1060_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1060_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1060_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1060_shape_4_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1060_shape_5_score_92.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1060_shape_6_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1060_shape_7_score_83.png with score: 0.83
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1061(1)_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1061(1)_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1061(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1061(1)_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_1061_shape_0_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062(1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062(1)_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062(1)_shape_3_score_91.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062(1)_shape_4_score_84.png with score: 0.85
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062(1)_shape_5_score_71.png with score: 0.72
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1062_shape_4_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1063_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1063_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1063_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1063_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1063_shape_4_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1063_shape_5_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1063_shape_6_score_90.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1063_shape_7_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1065(1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1065(1)_shape_1_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1065(1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1065(1)_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1065(1)_shape_4_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1065(1)_shape_5_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1065(1)_shape_6_score_94.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1065(1)_shape_7_score_90.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_1066(1)_shape_0_score_98.png with score: 0.99
# ...
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162114_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162114_shape_4_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162114_shape_5_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162114_shape_6_score_78.png with score: 0.79
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162114_shape_7_score_76.png with score: 0.76
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162117_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162117_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162117_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162117_shape_3_score_91.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162117_shape_4_score_91.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162117_shape_5_score_81.png with score: 0.81
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162117_shape_6_score_72.png with score: 0.73
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162252_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162252_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162252_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162252_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162252_shape_4_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162252_shape_5_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162252_shape_6_score_86.png with score: 0.86
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162252_shape_7_score_75.png with score: 0.76
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162254_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162254_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162254_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162254_shape_3_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162254_shape_4_score_90.png with score: 0.91
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162254_shape_5_score_83.png with score: 0.84
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162254_shape_6_score_75.png with score: 0.76
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162258_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162258_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162258_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162258_shape_3_score_85.png with score: 0.85
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162258_shape_4_score_79.png with score: 0.80
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162258_shape_5_score_72.png with score: 0.72
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162258_shape_6_score_71.png with score: 0.72
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162301_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162301_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162301_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162301_shape_3_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162301_shape_4_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162301_shape_5_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162301_shape_6_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162301_shape_7_score_84.png with score: 0.84
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162329_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162329_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162329_shape_2_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162329_shape_3_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162329_shape_4_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162329_shape_5_score_95.png with score: 0.95
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162329_shape_6_score_87.png with score: 0.88
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162329_shape_7_score_82.png with score: 0.82
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162329_shape_8_score_79.png with score: 0.79
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162353_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162353_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162353_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162353_shape_3_score_95.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162353_shape_4_score_93.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162353_shape_5_score_92.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162353_shape_6_score_74.png with score: 0.75
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162401_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162401_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162401_shape_2_score_94.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162401_shape_3_score_91.png with score: 0.92
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162401_shape_4_score_82.png with score: 0.82
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162401_shape_5_score_71.png with score: 0.71
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162406_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162406_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162406_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162406_shape_3_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162406_shape_4_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162406_shape_5_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162406_shape_6_score_94.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162406_shape_7_score_80.png with score: 0.80
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_20240708_162406_shape_8_score_77.png with score: 0.78
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_20240708_162406_shape_9_score_70.png with score: 0.71
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0333_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0333_shape_1_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0333_shape_2_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0333_shape_3_score_96.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0333_shape_4_score_89.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0333_shape_5_score_78.png with score: 0.79
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0341_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0341_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0341_shape_2_score_75.png with score: 0.75
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0346_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0346_shape_1_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0346_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0368_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0368_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0649_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0649_shape_1_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E0649_shape_2_score_92.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\turmeric\IMG_E0815_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E1040_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E1040_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E1040_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E1040_shape_3_score_93.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E1042_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E1042_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\IMG_E1042_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.50 PM_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.50 PM_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.50 PM_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.50 PM_shape_3_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.50 PM_shape_4_score_92.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.50 PM_shape_5_score_89.png with score: 0.90
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.50 PM_shape_6_score_87.png with score: 0.87
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.50 PM_shape_7_score_73.png with score: 0.73
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.52 PM (1)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.52 PM (1)_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.52 PM (1)_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.52 PM_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.52 PM_shape_1_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.52 PM_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.52 PM_shape_3_score_88.png with score: 0.89
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.53 PM (1)_shape_0_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.53 PM (1)_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.53 PM (1)_shape_2_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.53 PM (1)_shape_3_score_97.png with score: 0.97
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.53 PM (1)_shape_4_score_91.png with score: 0.92
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.53 PM (1)_shape_5_score_81.png with score: 0.81
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.53 PM_shape_0_score_98.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.53 PM_shape_1_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\turmeric\WhatsApp Image 2024-06-30 at 8.47.54 PM (2)_shape_0_score_86.png with score: 0.86
# Cropped leaf saved at: ./cropped-leaves\turmeric\WhatsApp Image 2024-06-30 at 8.47.54 PM (3)_shape_0_score_97.png with score: 0.98
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.54 PM_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.54 PM_shape_1_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.54 PM_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.54 PM_shape_3_score_93.png with score: 0.93
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.54 PM_shape_4_score_70.png with score: 0.70
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM (2)_shape_0_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM (2)_shape_1_score_99.png with score: 1.00
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM (2)_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM (2)_shape_3_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM_shape_2_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM_shape_3_score_96.png with score: 0.96
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM_shape_4_score_93.png with score: 0.94
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM_shape_5_score_81.png with score: 0.81
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.55 PM_shape_6_score_80.png with score: 0.81
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.56 PM_shape_0_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.56 PM_shape_1_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.56 PM_shape_2_score_99.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.56 PM_shape_3_score_98.png with score: 0.99
# Cropped leaf saved at: ./cropped-leaves\maize\WhatsApp Image 2024-06-30 at 8.47.56 PM_shape_4_score_90.png with score: 0.91

# %%
#On train set

import os
import json

# Define the paths
labels_folder = "./train-labels"
images_folder = './train'

# Loop through each JSON file in the labels folder
for filename in os.listdir(labels_folder):
    if filename.endswith('.json'):
        # Full path to the JSON file
        json_path = os.path.join(labels_folder, filename)

        # Open and load the JSON file
        with open(json_path, 'r') as file:
            data = json.load(file)

        # Update the imagePath to include the full path to the images folder
        image_filename = data.get('imagePath', '')
        new_image_path = os.path.join(images_folder, image_filename)

        # Update the imagePath in the JSON data
        data['imagePath'] = new_image_path

        # Save the updated JSON file
        with open(json_path, 'w') as file:
            json.dump(data, file, indent=4)

        print(f'Updated {filename}')

print("All JSON files have been updated.")
# Out:
# Updated 20240630_100802AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_101025AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_101239AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_101515AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_101523AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_101925AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_101929AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_102046AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_102226AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_102253AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_102536AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_102546AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_102847AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_103114AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_103118AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_105554AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_105656AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_105732AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_105735AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_105750AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_105911AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_105940AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_105944AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_105946AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110015AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110022AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110053AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110058AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110102AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110104AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110107AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110224AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110227AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110230AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110458AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110618AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110621AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110721AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110904AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_110958AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_111054AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_111058AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_111101AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_111104AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_111229AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_111234AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_111240AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_111713AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_111917AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_112018AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_112247AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_112432AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_112444AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_112447AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_112956AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_113008AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_113020AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_113304AM_Sunday_ByGPSMapCamera.json
# Updated 20240630_120804PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_120926PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_120956PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121008PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121016PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121118PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121154PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121200PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121210PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121222PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121316PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121328PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121411PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121425PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121427PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121534PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121537PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121630PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121642PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121753PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121811PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121816PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121831PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_121913PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_122242PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_122248PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_122252PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_122323PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_122351PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_122419PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_122424PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_122909PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_122923PM_Sunday_ByGPSMapCamera.json
# Updated 20240630_74356AMByGPSMapCamera.json
# Updated 20240630_74526AMByGPSMapCamera.json
# Updated 20240630_74528AMByGPSMapCamera.json
# Updated 20240630_74619AMByGPSMapCamera.json
# Updated 20240630_74636AMByGPSMapCamera.json
# Updated 20240630_74701AMByGPSMapCamera.json
# Updated 20240630_74708AMByGPSMapCamera.json
# Updated 20240630_74732AMByGPSMapCamera.json
# Updated 20240630_74741AMByGPSMapCamera.json
# Updated 20240630_74746AMByGPSMapCamera.json
# Updated 20240630_74754AMByGPSMapCamera.json
# Updated 20240630_80619AMByGPSMapCamera.json
# Updated 20240701_122042PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122102PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122141PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122158PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122207PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122309PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122332PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122444PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122511PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122519PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122526PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122553PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122605PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122656PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122717PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122754PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122827PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122844PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122849PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122852PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122859PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122910PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122927PM_Monday_ByGPSMapCamera.json
# Updated 20240701_122934PM_Monday_ByGPSMapCamera.json
# Updated 20240701_123013PM_Monday_ByGPSMapCamera.json
# Updated 20240701_123050PM_Monday_ByGPSMapCamera.json
# Updated 20240701_123055PM_Monday_ByGPSMapCamera.json
# Updated 20240701_123229PM_Monday_ByGPSMapCamera.json
# Updated 20240701_123443PM_Monday_ByGPSMapCamera.json
# Updated 20240701_123449PM_Monday_ByGPSMapCamera.json
# Updated DSC05840.json
# Updated DSC05843.json
# Updated DSC05859.json
# Updated DSC05862.json
# Updated DSC05874.json
# Updated DSC05880.json
# Updated DSC05881.json
# Updated DSC05882.json
# Updated DSC05906.json
# Updated DSC05915.json
# Updated DSC05921.json
# Updated DSC05923.json
# Updated DSC05926.json
# Updated DSC05933.json
# Updated DSC05935.json
# Updated DSC05938.json
# Updated DSC05949.json
# Updated DSC05950.json
# Updated DSC05951.json
# Updated DSC05955.json
# Updated DSC05957.json
# Updated DSC05958.json
# Updated DSC05959.json
# Updated DSC05969.json
# Updated DSC05973.json
# Updated DSC05975.json
# Updated DSC05979.json
# Updated DSC05980.json
# Updated DSC05982.json
# Updated DSC05983.json
# Updated DSC05991.json
# Updated DSC05995.json
# Updated DSC05996.json
# Updated DSC05999.json
# Updated DSC06000.json
# Updated DSC06006.json
# Updated DSC06007.json
# Updated DSC06008.json
# Updated DSC06012.json
# Updated DSC06025.json
# Updated DSC06027.json
# Updated DSC06029.json
# Updated DSC06030.json
# Updated DSC06035.json
# Updated DSC06037.json
# Updated DSC06038.json
# Updated DSC06039.json
# Updated DSC06040.json
# Updated DSC06041.json
# Updated DSC06042.json
# Updated DSC06044.json
# Updated DSC06045.json
# Updated DSC06046.json
# Updated DSC06060.json
# Updated DSC06061.json
# Updated DSC06062.json
# Updated DSC06064.json
# Updated DSC06067.json
# Updated DSC06068.json
# Updated DSC06074.json
# Updated DSC06076.json
# Updated DSC06077.json
# Updated DSC06083.json
# Updated DSC06085.json
# Updated DSC06087.json
# Updated EGXK4367.json
# Updated IMG_0028.json
# Updated IMG_0029.json
# Updated IMG_0045.json
# Updated IMG_0046.json
# Updated IMG_0060.json
# Updated IMG_0061.json
# Updated IMG_0062.json
# Updated IMG_0063.json
# Updated IMG_0064.json
# Updated IMG_0066.json
# Updated IMG_0067.json
# Updated IMG_0068.json
# Updated IMG_0069.json
# Updated IMG_0071.json
# Updated IMG_0082.json
# Updated IMG_0096.json
# Updated IMG_0107.json
# Updated IMG_0111.json
# Updated IMG_0115.json
# Updated IMG_0122.json
# Updated IMG_0177.json
# Updated IMG_0184.json
# Updated IMG_0187.json
# Updated IMG_0193.json
# Updated IMG_0198.json
# Updated IMG_0203.json
# Updated IMG_0205.json
# Updated IMG_0207.json
# Updated IMG_0212.json
# Updated IMG_0223.json
# Updated IMG_0226.json
# Updated IMG_0236.json
# Updated IMG_0241.json
# Updated IMG_0245.json
# Updated IMG_0261.json
# Updated IMG_0266.json
# Updated IMG_0279.json
# Updated IMG_0281.json
# Updated IMG_0296.json
# Updated IMG_0325.json
# Updated IMG_0327.json
# Updated IMG_0332.json
# Updated IMG_0333.json
# Updated IMG_0334.json
# Updated IMG_0337.json
# Updated IMG_0338.json
# Updated IMG_0347.json
# Updated IMG_0355.json
# Updated IMG_0359.json
# Updated IMG_0407.json
# Updated IMG_0438.json
# Updated IMG_0439.json
# Updated IMG_0445.json
# Updated IMG_0446.json
# Updated IMG_0447.json
# Updated IMG_0450.json
# Updated IMG_0453.json
# Updated IMG_0457.json
# Updated IMG_0458.json
# Updated IMG_0459.json
# Updated IMG_0465.json
# Updated IMG_0473.json
# Updated IMG_0512.json
# Updated IMG_0650.json
# Updated IMG_0690.json
# Updated IMG_0692.json
# Updated IMG_0693.json
# Updated IMG_0694.json
# Updated IMG_0698.json
# Updated IMG_0725.json
# Updated IMG_0731.json
# Updated IMG_0734.json
# Updated IMG_0749.json
# Updated IMG_0790(1).json
# Updated IMG_0795.json
# Updated IMG_0796.json
# Updated IMG_0797.json
# Updated IMG_0805(1).json
# Updated IMG_0805.json
# Updated IMG_0806.json
# Updated IMG_0808.json
# Updated IMG_0809.json
# Updated IMG_0814(1).json
# Updated IMG_0815(1).json
# Updated IMG_0818(1).json
# Updated IMG_0820.json
# Updated IMG_0823(1).json
# Updated IMG_0829(1).json
# Updated IMG_0832.json
# Updated IMG_0833(1).json
# Updated IMG_0836(1).json
# Updated IMG_0838.json
# Updated IMG_0840.json
# Updated IMG_0843(1).json
# Updated IMG_0862.json
# Updated IMG_0863(1).json
# Updated IMG_0863.json
# Updated IMG_0871.json
# Updated IMG_0873(1).json
# Updated IMG_0877(1).json
# Updated IMG_0879.json
# Updated IMG_0881.json
# Updated IMG_0882.json
# Updated IMG_0883.json
# Updated IMG_0884.json
# Updated IMG_0885(1).json
# Updated IMG_0887.json
# Updated IMG_0888(1).json
# Updated IMG_0889.json
# Updated IMG_0897(1).json
# Updated IMG_0897.json
# Updated IMG_0902(1).json
# Updated IMG_0903.json
# Updated IMG_0909.json
# Updated IMG_0911.json
# Updated IMG_0914(1).json
# Updated IMG_0915(1).json
# Updated IMG_0917.json
# Updated IMG_0918.json
# Updated IMG_0922(1).json
# Updated IMG_0922.json
# Updated IMG_0923.json
# Updated IMG_0924(1).json
# Updated IMG_0928.json
# Updated IMG_0929(1).json
# Updated IMG_0929.json
# Updated IMG_0931(1).json
# Updated IMG_0932(1).json
# Updated IMG_0934(1).json
# Updated IMG_0934.json
# Updated IMG_0935(1).json
# Updated IMG_0936.json
# Updated IMG_0937(1).json
# Updated IMG_0938.json
# Updated IMG_0939(1).json
# Updated IMG_0939.json
# Updated IMG_0940.json
# Updated IMG_0941(1).json
# Updated IMG_0943(1).json
# Updated IMG_0948(1).json
# Updated IMG_0949(1).json
# Updated IMG_0950.json
# Updated IMG_0953(1).json
# Updated IMG_0953.json
# Updated IMG_0954(1).json
# Updated IMG_0955.json
# Updated IMG_0963(1).json
# Updated IMG_0963.json
# Updated IMG_0965.json
# Updated IMG_0966.json
# Updated IMG_0967(1).json
# Updated IMG_0967.json
# Updated IMG_0968.json
# Updated IMG_0970(1).json
# Updated IMG_0972(1).json
# Updated IMG_0973(1).json
# Updated IMG_0974(1).json
# Updated IMG_0974.json
# Updated IMG_0975.json
# Updated IMG_0980.json
# Updated IMG_0982(1).json
# Updated IMG_0983.json
# Updated IMG_0985(1).json
# Updated IMG_0986(1).json
# Updated IMG_0987(1).json
# Updated IMG_0990.json
# Updated IMG_0992(1).json
# Updated IMG_0994(1).json
# Updated IMG_0994.json
# Updated IMG_0997(1).json
# Updated IMG_0997.json
# Updated IMG_1001.json
# Updated IMG_1010.json
# Updated IMG_1011.json
# Updated IMG_1012.json
# Updated IMG_1014.json
# Updated IMG_1017(1).json
# All JSON files have been updated.

# %%
#Training set

import os
import cv2
import json
import numpy as np

# Folder paths
labelme_folder = "./train-labels"  # Path to your Labelme JSON files
image_folder = "./train"  # Path where the images are stored
output_crops_folder = "./cropped-leaves-2"  # Path to save cropped shapes

# Create the main output directory if it doesn't exist
if not os.path.exists(output_crops_folder):
    os.makedirs(output_crops_folder)

# Create subfolders for each class
class_names = ["maize", "tumeric"]
for class_name in class_names:
    class_folder = os.path.join(output_crops_folder, class_name)
    if not os.path.exists(class_folder):
        os.makedirs(class_folder)

# Iterate over each JSON file in the Labelme folder
# Iterate over each JSON file in the Labelme folder
for json_file in os.listdir(labelme_folder):
    if json_file.endswith('.json'):
        json_path = os.path.join(labelme_folder, json_file)

        # Load the JSON file
        with open(json_path) as f:
            data = json.load(f)

        # Modify the imagePath to point to the correct folder
        original_image_path = data['imagePath']
        # Extract the filename only and ignore the original path structure
        modified_image_path = os.path.basename(original_image_path)  
        data['imagePath'] = modified_image_path

        # Load the image using the corrected path in the `./train` folder
        image_path = os.path.join(image_folder, modified_image_path)
        image = cv2.imread(image_path)

        # Check if the image was loaded successfully
        if image is None:
            print(f"Warning: Unable to load image at {image_path}")
            continue  # Skip this JSON file and move to the next one

        # Process each shape in the JSON
        for shape in data['shapes']:
            # Extract polygon points
            points = np.array(shape['points'], dtype=np.int32)
            class_name = shape['label']

            # Create a binary mask from the polygon
            mask = np.zeros(image.shape[:2], dtype=np.uint8)
            cv2.fillPoly(mask, [points], 1)  # Fill the polygon in the mask

            # Find contours of the mask
            contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            # Crop and save each detected leaf using the mask
            for i, contour in enumerate(contours):
                # Create a blank image for cropping
                crop_mask = np.zeros_like(image)

                # Draw the contour on the blank image
                cv2.drawContours(crop_mask, [contour], -1, (255, 255, 255), thickness=cv2.FILLED)

                # Mask the original image
                cropped_leaf = cv2.bitwise_and(image, crop_mask)

                # Get bounding box for the contour to crop the relevant part
                x, y, w, h = cv2.boundingRect(contour)
                cropped_leaf = cropped_leaf[y:y+h, x:x+w]

                # Determine the class folder based on the label
                if class_name in class_names:
                    class_folder = os.path.join(output_crops_folder, class_name)

                    # Save the cropped shape
                    crop_filename = f"{os.path.splitext(json_file)[0]}_shape_{i}.png"
                    crop_path = os.path.join(class_folder, crop_filename)
                    cv2.imwrite(crop_path, cropped_leaf)

                    print(f"Cropped leaf saved at: {crop_path} for class: {class_name}")

        # Save the modified JSON file with the updated imagePath
        with open(json_path, 'w') as f:
            json.dump(data, f, indent=4)

print("Processing complete.")
# Out:
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_100802AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_100802AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_100802AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101025AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101025AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101025AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101239AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101925AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101925AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101925AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101925AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101929AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101929AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101929AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101929AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_101929AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102226AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102226AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102226AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102253AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102536AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102536AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102536AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102546AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102546AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102546AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102546AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102546AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102847AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_102847AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_103114AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_103114AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105554AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105656AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105656AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105656AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105656AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105656AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105656AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105732AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105732AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105732AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105735AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105735AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105735AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105750AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105750AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105750AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105750AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105750AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105750AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105911AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105911AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105940AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105940AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105940AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105944AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105944AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105944AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105944AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105944AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105944AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105946AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105946AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105946AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_105946AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110015AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110015AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110022AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110022AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110022AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110022AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110053AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110053AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110053AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110053AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110053AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110102AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110102AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110102AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110102AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110104AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110104AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110104AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110104AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110104AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110107AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110107AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110107AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110107AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110107AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110224AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110224AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110224AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110224AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110224AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110224AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110224AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110224AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110227AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110227AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110227AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110227AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110227AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110230AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110230AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110230AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110230AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110230AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110230AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110458AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110458AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110458AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110618AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110618AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110618AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110621AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110621AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110621AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110721AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110721AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110904AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_110904AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111054AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111054AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111054AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111054AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111054AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111058AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111101AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111101AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111101AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111101AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111101AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111101AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111104AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111104AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111104AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111104AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111229AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111229AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111229AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111229AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111234AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111234AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111234AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111234AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111234AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111240AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111240AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111240AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111240AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111713AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111713AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111713AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111713AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111713AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111917AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111917AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_111917AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112018AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112018AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112247AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112247AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112247AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112247AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112247AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112432AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112432AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112432AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112444AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112444AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112444AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112444AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112444AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112444AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112444AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112447AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112447AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112447AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112447AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112447AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112956AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112956AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112956AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_112956AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113008AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113008AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113008AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113008AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113304AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113304AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113304AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113304AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113304AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_113304AM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120804PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120804PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120804PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120804PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120804PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120804PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120804PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120926PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120926PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120926PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120926PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120926PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120956PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120956PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_120956PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121008PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121008PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121008PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121016PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121016PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121016PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121016PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121118PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121118PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121118PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121118PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121118PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121118PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121118PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121118PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121118PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121154PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121154PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121154PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121154PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121200PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121200PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121200PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121200PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121200PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121222PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121222PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121316PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121316PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121316PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121328PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121328PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121328PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121328PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121328PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121328PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121411PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121411PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121411PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121411PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121425PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121425PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121425PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121427PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121427PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121427PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121534PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121534PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121534PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121537PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121537PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121537PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121537PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121537PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121537PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121537PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121642PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121642PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121642PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121753PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121753PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121753PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121753PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121811PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121811PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121811PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121811PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121811PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121811PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121811PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121816PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121831PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121831PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121831PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121831PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121913PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121913PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_121913PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122242PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122242PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122248PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122248PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122248PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122248PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122248PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122248PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122248PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122248PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122252PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122252PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122252PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122252PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122252PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122252PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122323PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122323PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122323PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122323PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122323PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122323PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122323PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122323PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122351PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122351PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122351PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122351PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122419PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122419PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122419PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122419PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122424PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122424PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122424PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122424PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122424PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122424PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122909PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122909PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122909PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122909PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122909PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122909PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122909PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122923PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122923PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122923PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122923PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_122923PM_Sunday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74356AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74356AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74356AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74356AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74356AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74526AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74526AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74526AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74528AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74528AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74528AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74619AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74619AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74636AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74636AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74701AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74701AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74701AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74701AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74708AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74708AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74708AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74708AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74741AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74754AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74754AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_74754AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_80619AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240630_80619AMByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122042PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122042PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122042PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122042PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122102PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122102PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122102PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122141PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122141PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122141PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122141PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122141PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122141PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122141PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122141PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122158PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122158PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122158PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122158PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122158PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122158PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\20240701_122158PM_Monday_ByGPSMapCamera_shape_0.png for class: maize
# ...
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0940_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0940_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0940_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0940_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0940_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0940_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0948(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0948(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0948(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0948(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0949(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0949(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0949(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0949(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0949(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0949(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0949(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0950_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0950_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0950_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0950_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0953(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0953(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0953(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0953(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0953(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0953_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0953_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0953_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0953_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0954(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0954(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0954(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0954(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0955_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0963(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0963(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0963_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0963_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0963_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0963_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0963_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0963_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0965_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0965_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0965_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0965_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0965_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0966_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0966_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0966_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0966_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0967_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0968_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0968_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0968_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0968_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0968_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0968_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0970(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0970(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0970(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0970(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0970(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0972(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0972(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0972(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0972(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0972(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0972(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0973(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0973(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0973(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0973(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0974_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0975_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0975_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0975_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0975_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0975_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0975_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0982(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0982(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0982(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0982(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0982(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0982(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0982(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0982(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0983_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0983_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0983_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0983_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0983_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0983_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0983_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0985(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0985(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0985(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0985(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0985(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0985(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0985(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0985(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0986(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0986(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0986(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0986(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0987(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0987(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0990_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0990_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0990_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0990_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0990_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0992(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0994_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997(1)_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_0997_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1001_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1001_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1001_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1001_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1001_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1001_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1010_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1010_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1010_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1010_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1011_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1011_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1011_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1011_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1011_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1014_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1014_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1014_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1014_shape_0.png for class: maize
# Cropped leaf saved at: ./cropped-leaves-2\maize\IMG_1017(1)_shape_0.png for class: maize
# Processing complete.
